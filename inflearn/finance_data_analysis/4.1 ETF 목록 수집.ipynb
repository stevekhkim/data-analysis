# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/finance-data-analysis/blob/main/4.1%20ETF%20%EB%AA%A9%EB%A1%9D%20%EC%88%98%EC%A7%91-input.ipynb)
#
#
# ## ETF란?
# * ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF)이 투명하게 공개되어 있고, 장중에는 실시간으로 순자산가치(NAV)가 제공되어 거래에 참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
#     * 출처 : [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)
#
#
# ## 크롬 브라우저의 네트워크 정보를 통한 데이터 수집
# * json 데이터 수집과 파일저장 방법
#
# * [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)

# %%
# 라이브러리를 불러옵니다.
# 데이터 분석을 위한 pandas, 수치계산을 위한 numpy, http 요청을 위한 requests를 받아옵니다.
import pandas as pd
import numpy as np
import requests

# %%
# 수집할 url을 가져옵니다.
url = 'https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc'
url
# Out:
# 'https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc'

# %% [markdown]
# ## Pandas를 통한 요청

# %%
pd.read_html(url)  # 아무것도 불러오지 못함
# Out:
# []

# %% [markdown]
# ## JSON
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/JSON_vector_logo.svg/300px-JSON_vector_logo.svg.png" width="100">
#
# JSON(제이슨, JavaScript Object Notation)은 속성-값 쌍( attribute–value pairs and array data types (or any other serializable value)) 또는 "키-값 쌍"으로 이루어진 데이터 오브젝트를 전달하기 위해 인간이 읽을 수 있는 텍스트를 사용하는 개방형 표준 포맷이다. 비동기 브라우저/서버 통신 (AJAX)을 위해, 넓게는 XML(AJAX가 사용)을 대체하는 주요 데이터 포맷이다. 특히, 인터넷에서 자료를 주고 받을 때 그 자료를 표현하는 방법으로 알려져 있다. 자료의 종류에 큰 제한은 없으며, 특히 컴퓨터 프로그램의 변수값을 표현하는 데 적합하다.
# 본래는 자바스크립트 언어로부터 파생되어 자바스크립트의 구문 형식을 따르지만 언어 독립형 데이터 포맷이다. 즉, 프로그래밍 언어나 플랫폼에 독립적이므로, 구문 분석 및 JSON 데이터 생성을 위한 코드는 C, C++, C#, 자바, 자바스크립트, 펄, 파이썬 등 수많은 프로그래밍 언어에서 쉽게 이용할 수 있다.
#
# * 출처 : [JSON - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/JSON)

# %% [markdown]
# ## requests를 통한 HTTP 요청
# * [Requests: HTTP for Humans™ — Requests documentation](https://requests.readthedocs.io/en/master/)

# %%
# requests 라이브러리를 통해 url을 받아옵니다.
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"resultCode":"success","result":{"etfItemList":[{"itemcode":"069500","etfTabCode":1,"itemname":"KODEX 200","nowVal":39420,"risefall":"2","changeVal":400,"changeRate":1.03,"nav":39436.0,"threeMonthEarnRate":-9.668,"quant":2570170,"amonut":101274,"marketSum":48270},{"itemcode":"371460","etfTabCode":4,"itemname":"TIGER 차이나전기차SOLACTIVE","nowVal":17850,"risefall":"2","changeVal":440,"changeRate":2.53,"nav":null,"threeMonthEarnRate":7.2716,"quant":8417623,"amonut":148973,"marketSum":22977},{"itemcode":"102110","etfTabCode":1,"itemname":"TIGER 200","nowVal":39460,"risefall":"2","changeVal":415,"changeRate":1.06,"nav":39472.0,"threeMonthEarnRate":-9.6074,"quant":430561,"amonut":16985,"marketSum":21466},{"itemcode":"153130","etfTabCode":6,"itemname":"KODEX 단기채권","nowVal":102965,"risefall":"5","changeVal":-5,"changeRate":0.0,"nav":102964.0,"threeMonthEarnRate":0.1215,"quant":10120,"amonut":1041,"marketSum":21277},{"itemcode":"252670","etfTabCode":3,"itemname":"KODEX 200선물인버스2X","nowVal":2245,"risefall":"5","changeVal":-50,"changeRate":-2.18,"nav":2239.0,"threeMonthEarnRate":20.0534,"quant":187196187,"amonut":421296,"marketSum":19906},{"itemcode":"122630","etfTabCode":3,"itemname":"KODEX 레버리지","nowVal":23535,"risefall":"2","changeVal":485,"changeRate":2.1,"nav":23620.0,"threeMonthEarnRate":-18.7608,"quant":19143272,"amonut":449886,"marketSum":19299},{"itemcode":"214980","etfTabCode":6,"itemname":"KODEX 단기채권PLUS","nowVal":103275,"risefall":"2","changeVal":5,"changeRate":0.0,"nav":103278.0,"threeMonthEarnRate":0.126,"quant":2522411,"amonut":260501,"marketSum":18504},{"itemcode":"102780","etfTabCode":2,"itemname":"KODEX 삼성그룹","nowVal":9840,"risefall":"2","changeVal":180,"changeRate":1.86,"nav":9864.0,"threeMonthEarnRate":-6.2411,"quant":414906,"amonut":4076,"marketSum":17623},{"itemcode":"157450","etfTabCode":6,"itemname":"TIGER 단기통안채","nowVal":100370,"risefall":"3","changeVal":0,"changeRate":0.0,"nav":100367.0,"threeMonthEarnRate":0.1396,"quant":30457,"amonut":3056,"marketSum":14671},{"itemcode":"273130","etfTabCode":6,"itemname":"KODEX 종합채권(AA-이상)액티브","nowVal":107840,"risefall":"2","changeVal":5,"changeRate":0.0,"nav":107801.0,"threeMonthEarnRate":-1.25,"quant":23285,"amonut":2509,"marketSum":14387},{"itemcode":"133690","etfTabCode":4,"itemname":"TIGER 미국나스닥100","nowVal":80005,"risefall":"2","changeVal":1000,"changeRate":1.27,"nav":null,"threeMonthEarnRate":4.6966,"quant":108453,"amonut":8672,"marketSum":13761},{"itemcode":"292150","etfTabCode":2,"itemname":"TIGER TOP10","nowVal":13285,"risefall":"2","changeVal":115,"changeRate":0.87,"nav":13288.0,"threeMonthEarnRate":-12.1944,"quant":221712,"amonut":2942,"marketSum":12255},{"itemcode":"278530","etfTabCode":1,"itemname":"KODEX 200TR","nowVal":12890,"risefall":"2","changeVal":130,"changeRate":1.02,"nav":12913.0,"threeMonthEarnRate":-9.7971,"quant":76484,"amonut":986,"marketSum":11678},{"itemcode":"114800","etfTabCode":3,"itemname":"KODEX 인버스","nowVal":4070,"risefall":"5","changeVal":-45,"changeRate":-1.09,"nav":4065.0,"threeMonthEarnRate":10.0,"quant":32468613,"amonut":132306,"marketSum":11376},{"itemcode":"305540","etfTabCode":2,"itemname":"TIGER 2차전지테마","nowVal":23470,"risefall":"5","changeVal":-15,"changeRate":-0.06,"nav":23459.0,"threeMonthEarnRate":18.0286,"quant":2035599,"amonut":47764,"marketSum":11078},{"itemcode":"305720","etfTabCode":2,"itemname":"KODEX 2차전지산업","nowVal":23540,"risefall":"5","changeVal":-5,"changeRate":-0.02,"nav":23548.0,"threeMonthEarnRate":14.9975,"quant":1427169,"amonut":33591,"marketSum":10970},{"itemcode":"148020","etfTabCode":1,"itemname":"KBSTAR 200","nowVal":39500,"risefall":"2","changeVal":415,"changeRate":1.06,"nav":39526.0,"threeMonthEarnRate":-9.5883,"quant":151047,"amonut":5970,"marketSum":10724},{"itemcode":"278540","etfTabCode":1,"itemname":"KODEX MSCI Korea TR","nowVal":12555,"risefall":"2","changeVal":140,"changeRate":1.13,"nav":12558.0,"threeMonthEarnRate":-10.2253,"quant":481525,"amonut":6040,"marketSum":10107},{"itemcode":"310970","etfTabCod ...

# %% [markdown]
# ### JSON 타입으로 데이터 받기

# %%
# requests 의 응답을 json 타입으로 받습니다.
etf_json = response.json()
etf_json
# Out:
# {'resultCode': 'success',
#  'result': {'etfItemList': [{'itemcode': '069500',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200',
#     'nowVal': 39420,
#     'risefall': '2',
#     'changeVal': 400,
#     'changeRate': 1.03,
#     'nav': 39436.0,
#     'threeMonthEarnRate': -9.668,
#     'quant': 2570170,
#     'amonut': 101274,
#     'marketSum': 48270},
#    {'itemcode': '371460',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'nowVal': 17850,
#     'risefall': '2',
#     'changeVal': 440,
#     'changeRate': 2.53,
#     'nav': None,
#     'threeMonthEarnRate': 7.2716,
#     'quant': 8417623,
#     'amonut': 148973,
#     'marketSum': 22977},
#    {'itemcode': '102110',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200',
#     'nowVal': 39460,
#     'risefall': '2',
#     'changeVal': 415,
#     'changeRate': 1.06,
#     'nav': 39472.0,
#     'threeMonthEarnRate': -9.6074,
#     'quant': 430561,
#     'amonut': 16985,
#     'marketSum': 21466},
#    {'itemcode': '153130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권',
#     'nowVal': 102965,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 102964.0,
#     'threeMonthEarnRate': 0.1215,
#     'quant': 10120,
#     'amonut': 1041,
#     'marketSum': 21277},
#    {'itemcode': '252670',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 200선물인버스2X',
#     'nowVal': 2245,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -2.18,
#     'nav': 2239.0,
#     'threeMonthEarnRate': 20.0534,
#     'quant': 187196187,
#     'amonut': 421296,
#     'marketSum': 19906},
#    {'itemcode': '122630',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 레버리지',
#     'nowVal': 23535,
#     'risefall': '2',
#     'changeVal': 485,
#     'changeRate': 2.1,
#     'nav': 23620.0,
#     'threeMonthEarnRate': -18.7608,
#     'quant': 19143272,
#     'amonut': 449886,
#     'marketSum': 19299},
#    {'itemcode': '214980',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권PLUS',
#     'nowVal': 103275,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 103278.0,
#     'threeMonthEarnRate': 0.126,
#     'quant': 2522411,
#     'amonut': 260501,
#     'marketSum': 18504},
#    {'itemcode': '102780',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹',
#     'nowVal': 9840,
#     'risefall': '2',
#     'changeVal': 180,
#     'changeRate': 1.86,
#     'nav': 9864.0,
#     'threeMonthEarnRate': -6.2411,
#     'quant': 414906,
#     'amonut': 4076,
#     'marketSum': 17623},
#    {'itemcode': '157450',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기통안채',
#     'nowVal': 100370,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100367.0,
#     'threeMonthEarnRate': 0.1396,
#     'quant': 30457,
#     'amonut': 3056,
#     'marketSum': 14671},
#    {'itemcode': '273130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'nowVal': 107840,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 107801.0,
#     'threeMonthEarnRate': -1.25,
#     'quant': 23285,
#     'amonut': 2509,
#     'marketSum': 14387},
#    {'itemcode': '133690',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100',
#     'nowVal': 80005,
#     'risefall': '2',
#     'changeVal': 1000,
#     'changeRate': 1.27,
#     'nav': None,
#     'threeMonthEarnRate': 4.6966,
#     'quant': 108453,
#     'amonut': 8672,
#     'marketSum': 13761},
#    {'itemcode': '292150',
#     'etfTabCode': 2,
#     'itemname': 'TIGER TOP10',
#     'nowVal': 13285,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.87,
#     'nav': 13288.0,
#     'threeMonthEarnRate': -12.1944,
#     'quant': 221712,
#     'amonut': 2942,
#     'marketSum': 12255},
#    {'itemcode': '278530',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200TR',
#     'nowVal': 12890,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 1.02,
#     'nav': 12913.0,
#     'threeMonthEarnRate': -9.7971,
#     'quant': 76484,
#     'amonut': 986,
#     'marketSum': 11678},
#    {'itemcode': '114800',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 인버스',
#     'nowVal': 4070,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -1.09,
#     'nav': 4065.0,
#     'threeMonthEarnRate': 10.0,
#     'quant': 32468613,
#     'amonut': 132306,
#     'marketSum': 11376},
#    {'itemcode': '305540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지테마',
#     'nowVal': 23470,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.06,
#     'nav': 23459.0,
#     'threeMonthEarnRate': 18.0286,
#     'quant': 2035599,
#     'amonut': 47764,
#     'marketSum': 11078},
#    {'itemcode': '305720',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업',
#     'nowVal': 23540,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.02,
#     'nav': 23548.0,
#     'threeMonthEarnRate': 14.9975,
#     'quant': 1427169,
#     'amonut': 33591,
#     'marketSum': 10970},
#    {'itemcode': '148020',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200',
#     'nowVal': 39500,
#     'risefall': '2',
#     'changeVal': 415,
#     'changeRate': 1.06,
#     'nav': 39526.0,
#     'threeMonthEarnRate': -9.5883,
#     'quant': 151047,
#     'amonut': 5970,
#     'marketSum': 10724},
#    {'itemcode': '278540',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea TR',
#     'nowVal': 12555,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 1.13,
#     'nav': 12558.0,
#     'threeMonthEarnRate': -10.2253,
#     'quant': 481525,
#     'amonut': 6040,
#     'marketSum': 10107},
#    {'itemcode': '310970',
#     'etfTabCode': 1,
#     'itemname': 'TIGER MSCI Korea TR',
#     'nowVal': 15780,
#     'risefall': '2',
#     'changeVal': 165,
#     'changeRate': 1.06,
#     'nav': 15779.0,
#     'threeMonthEarnRate': -10.5443,
#     'quant': 830,
#     'amonut': 13,
#     'marketSum': 8679},
#    {'itemcode': '139260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 IT',
#     'nowVal': 34155,
#     'risefall': '2',
#     'changeVal': 930,
#     'changeRate': 2.8,
#     'nav': 34143.0,
#     'threeMonthEarnRate': -13.0474,
#     'quant': 121578,
#     'amonut': 4130,
#     'marketSum': 8593},
#    {'itemcode': '233740',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥150 레버리지',
#     'nowVal': 14870,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.61,
#     'nav': 15033.0,
#     'threeMonthEarnRate': -7.4674,
#     'quant': 7626923,
#     'amonut': 112963,
#     'marketSum': 8461},
#    {'itemcode': '381170',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10 INDXX',
#     'nowVal': 11860,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 1.28,
#     'nav': None,
#     'threeMonthEarnRate': 4.5855,
#     'quant': 969922,
#     'amonut': 11490,
#     'marketSum': 8195},
#    {'itemcode': '091180',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 자동차',
#     'nowVal': 22205,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -0.52,
#     'nav': 22177.0,
#     'threeMonthEarnRate': -7.7866,
#     'quant': 249293,
#     'amonut': 5529,
#     'marketSum': 7905},
#    {'itemcode': '152100',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200',
#     'nowVal': 39965,
#     'risefall': '2',
#     'changeVal': 425,
#     'changeRate': 1.07,
#     'nav': 39979.0,
#     'threeMonthEarnRate': -9.3867,
#     'quant': 61819,
#     'amonut': 2472,
#     'marketSum': 7673},
#    {'itemcode': '105190',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200',
#     'nowVal': 39580,
#     'risefall': '2',
#     'changeVal': 410,
#     'changeRate': 1.05,
#     'nav': 39590.0,
#     'threeMonthEarnRate': -9.5522,
#     'quant': 438818,
#     'amonut': 17375,
#     'marketSum': 6966},
#    {'itemcode': '394670',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#     'nowVal': 11450,
#     'risefall': '2',
#     'changeVal': 330,
#     'changeRate': 2.97,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 2050621,
#     'amonut': 23263,
#     'marketSum': 6902},
#    {'itemcode': '360750',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500',
#     'nowVal': 13255,
#     'risefall': '2',
#     'changeVal': 145,
#     'changeRate': 1.11,
#     'nav': None,
#     'threeMonthEarnRate': 5.441,
#     'quant': 372103,
#     'amonut': 4929,
#     'marketSum': 6681},
#    {'itemcode': '364980',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX2차전지K-뉴딜',
#     'nowVal': 18240,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.14,
#     'nav': 18294.0,
#     'threeMonthEarnRate': 3.6363,
#     'quant': 1054100,
#     'amonut': 19305,
#     'marketSum': 6265},
#    {'itemcode': '293180',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200',
#     'nowVal': 39475,
#     'risefall': '2',
#     'changeVal': 435,
#     'changeRate': 1.11,
#     'nav': 39469.0,
#     'threeMonthEarnRate': -9.5834,
#     'quant': 12234,
#     'amonut': 483,
#     'marketSum': 5961},
#    {'itemcode': '069660',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200',
#     'nowVal': 39500,
#     'risefall': '2',
#     'changeVal': 440,
#     'changeRate': 1.13,
#     'nav': 39490.0,
#     'threeMonthEarnRate': -9.6524,
#     'quant': 4124,
#     'amonut': 162,
#     'marketSum': 5589},
#    {'itemcode': '381180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체나스닥',
#     'nowVal': 10540,
#     'risefall': '2',
#     'changeVal': 250,
#     'changeRate': 2.43,
#     'nav': None,
#     'threeMonthEarnRate': 3.6891,
#     'quant': 798699,
#     'amonut': 8406,
#     'marketSum': 5339},
#    {'itemcode': '314250',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국FANG플러스(H)',
#     'nowVal': 28950,
#     'risefall': '2',
#     'changeVal': 285,
#     'changeRate': 0.99,
#     'nav': None,
#     'threeMonthEarnRate': -0.31,
#     'quant': 124232,
#     'amonut': 3584,
#     'marketSum': 4777},
#    {'itemcode': '251340',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'nowVal': 4340,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.23,
#     'nav': 4348.0,
#     'threeMonthEarnRate': 1.5204,
#     'quant': 26365179,
#     'amonut': 114691,
#     'marketSum': 4700},
#    {'itemcode': '315930',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Top5PlusTR',
#     'nowVal': 18000,
#     'risefall': '2',
#     'changeVal': 205,
#     'changeRate': 1.15,
#     'nav': 17985.0,
#     'threeMonthEarnRate': -10.5591,
#     'quant': 3151,
#     'amonut': 56,
#     'marketSum': 4680},
#    {'itemcode': '294400',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200TR',
#     'nowVal': 46910,
#     'risefall': '2',
#     'changeVal': 445,
#     'changeRate': 0.96,
#     'nav': 46939.0,
#     'threeMonthEarnRate': -9.6843,
#     'quant': 35496,
#     'amonut': 1663,
#     'marketSum': 4644},
#    {'itemcode': '360200',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국S&P500',
#     'nowVal': 13350,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 1.14,
#     'nav': None,
#     'threeMonthEarnRate': 5.5252,
#     'quant': 138662,
#     'amonut': 1850,
#     'marketSum': 3978},
#    {'itemcode': '364960',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX BBIG K-뉴딜',
#     'nowVal': 12305,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.45,
#     'nav': 12309.0,
#     'threeMonthEarnRate': -11.2194,
#     'quant': 157869,
#     'amonut': 1938,
#     'marketSum': 3833},
#    {'itemcode': '385540',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#     'nowVal': 99360,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.04,
#     'nav': 99316.0,
#     'threeMonthEarnRate': -1.1245,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 3798},
#    {'itemcode': '226490',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스피',
#     'nowVal': 30370,
#     'risefall': '2',
#     'changeVal': 350,
#     'changeRate': 1.17,
#     'nav': 30374.0,
#     'threeMonthEarnRate': -8.1368,
#     'quant': 143774,
#     'amonut': 4366,
#     'marketSum': 3675},
#    {'itemcode': '196230',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기통안채',
#     'nowVal': 104645,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 104640.0,
#     'threeMonthEarnRate': 0.1723,
#     'quant': 797949,
#     'amonut': 83493,
#     'marketSum': 3604},
#    {'itemcode': '091170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 은행',
#     'nowVal': 7440,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 1.5,
#     'nav': 7461.0,
#     'threeMonthEarnRate': 1.5006,
#     'quant': 787218,
#     'amonut': 5837,
#     'marketSum': 3567},
#    {'itemcode': '229200',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥 150',
#     'nowVal': 14380,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.03,
#     'nav': 14525.0,
#     'threeMonthEarnRate': -3.3927,
#     'quant': 1420242,
#     'amonut': 20391,
#     'marketSum': 3494},
#    {'itemcode': '332500',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200TR',
#     'nowVal': 24065,
#     'risefall': '2',
#     'changeVal': 235,
#     'changeRate': 0.99,
#     'nav': 24082.0,
#     'threeMonthEarnRate': -9.649,
#     'quant': 5738,
#     'amonut': 138,
#     'marketSum': 3489},
#    {'itemcode': '367770',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn수소경제테마',
#     'nowVal': 12905,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.19,
#     'nav': 12897.0,
#     'threeMonthEarnRate': 0.3109,
#     'quant': 265547,
#     'amonut': 3424,
#     'marketSum': 3375},
#    {'itemcode': '251350',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 선진국MSCI World',
#     'nowVal': 20710,
#     'risefall': '2',
#     'changeVal': 265,
#     'changeRate': 1.3,
#     'nav': None,
#     'threeMonthEarnRate': 5.5555,
#     'quant': 85146,
#     'amonut': 1758,
#     'marketSum': 3355},
#    {'itemcode': '290130',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR ESG사회책임투자',
#     'nowVal': 12695,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 0.99,
#     'nav': 12694.0,
#     'threeMonthEarnRate': -11.0995,
#     'quant': 13975,
#     'amonut': 177,
#     'marketSum': 3301},
#    {'itemcode': '371160',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나항셍테크',
#     'nowVal': 8285,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.66,
#     'nav': None,
#     'threeMonthEarnRate': -15.4161,
#     'quant': 360484,
#     'amonut': 2982,
#     'marketSum': 3231},
#    {'itemcode': '367380',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국나스닥100',
#     'nowVal': 13735,
#     'risefall': '2',
#     'changeVal': 155,
#     'changeRate': 1.14,
#     'nav': None,
#     'threeMonthEarnRate': 4.7274,
#     'quant': 115427,
#     'amonut': 1585,
#     'marketSum': 2747},
#    {'itemcode': '272560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기국공채액티브',
#     'nowVal': 102235,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 102225.0,
#     'threeMonthEarnRate': 0.1812,
#     'quant': 432429,
#     'amonut': 44205,
#     'marketSum': 2618},
#    {'itemcode': '357870',
#     'etfTabCode': 7,
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'nowVal': 50465,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.03,
#     'nav': 50445.0,
#     'threeMonthEarnRate': 0.2084,
#     'quant': 4,
#     'amonut': 0,
#     'marketSum': 2576},
#    {'itemcode': '295040',
#     'etfTabCode': 1,
#     'itemname': 'SOL 200TR',
#     'nowVal': 13425,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 0.98,
#     'nav': 13437.0,
#     'threeMonthEarnRate': -9.7176,
#     'quant': 17919,
#     'amonut': 240,
#     'marketSum': 2557},
#    {'itemcode': '332940',
#     'etfTabCode': 1,
#     'itemname': 'HANARO MSCI Korea TR',
#     'nowVal': 15700,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.45,
#     'nav': 15761.0,
#     'threeMonthEarnRate': -10.8462,
#     'quant': 50,
#     'amonut': 0,
#     'marketSum': 2543},
#    {'itemcode': '385550',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#     'nowVal': 100125,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 100117.0,
#     'threeMonthEarnRate': 0.18,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 2538},
#    {'itemcode': '192090',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300',
#     'nowVal': 11995,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.04,
#     'nav': None,
#     'threeMonthEarnRate': -0.3738,
#     'quant': 100220,
#     'amonut': 1202,
#     'marketSum': 2495},
#    {'itemcode': '275980',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#     'nowVal': 18785,
#     'risefall': '2',
#     'changeVal': 345,
#     'changeRate': 1.87,
#     'nav': None,
#     'threeMonthEarnRate': -0.0533,
#     'quant': 53099,
#     'amonut': 992,
#     'marketSum': 2480},
#    {'itemcode': '143850',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'nowVal': 52045,
#     'risefall': '2',
#     'changeVal': 760,
#     'changeRate': 1.48,
#     'nav': None,
#     'threeMonthEarnRate': 2.059,
#     'quant': 26476,
#     'amonut': 1376,
#     'marketSum': 2459},
#    {'itemcode': '108450',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX 삼성그룹섹터가중',
#     'nowVal': 16435,
#     'risefall': '2',
#     'changeVal': 345,
#     'changeRate': 2.14,
#     'nav': 16435.0,
#     'threeMonthEarnRate': -5.1645,
#     'quant': 1553,
#     'amonut': 25,
#     'marketSum': 2449},
#    {'itemcode': '168580',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 중국본토CSI300',
#     'nowVal': 32000,
#     'risefall': '2',
#     'changeVal': 250,
#     'changeRate': 0.79,
#     'nav': None,
#     'threeMonthEarnRate': 0.1564,
#     'quant': 324122,
#     'amonut': 10356,
#     'marketSum': 2400},
#    {'itemcode': '132030',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물(H)',
#     'nowVal': 12120,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.08,
#     'nav': None,
#     'threeMonthEarnRate': -2.5724,
#     'quant': 63537,
#     'amonut': 771,
#     'marketSum': 2291},
#    {'itemcode': '245710',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 베트남VN30(합성)',
#     'nowVal': 23155,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.17,
#     'nav': None,
#     'threeMonthEarnRate': 10.4986,
#     'quant': 96910,
#     'amonut': 2221,
#     'marketSum': 2269},
#    {'itemcode': '091160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 반도체',
#     'nowVal': 32360,
#     'risefall': '2',
#     'changeVal': 840,
#     'changeRate': 2.66,
#     'nav': 32391.0,
#     'threeMonthEarnRate': -15.7731,
#     'quant': 230046,
#     'amonut': 7421,
#     'marketSum': 2233},
#    {'itemcode': '161510',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 고배당주',
#     'nowVal': 12850,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 1.02,
#     'nav': 12884.0,
#     'threeMonthEarnRate': 2.8411,
#     'quant': 107139,
#     'amonut': 1374,
#     'marketSum': 2159},
#    {'itemcode': '332930',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200TR',
#     'nowVal': 46985,
#     'risefall': '2',
#     'changeVal': 500,
#     'changeRate': 1.08,
#     'nav': 46984.0,
#     'threeMonthEarnRate': -9.566,
#     'quant': 724,
#     'amonut': 34,
#     'marketSum': 2020},
#    {'itemcode': '190620',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 단기통안채',
#     'nowVal': 100520,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 100514.0,
#     'threeMonthEarnRate': 0.1644,
#     'quant': 721,
#     'amonut': 72,
#     'marketSum': 1975},
#    {'itemcode': '261220',
#     'etfTabCode': 5,
#     'itemname': 'KODEX WTI원유선물(H)',
#     'nowVal': 12540,
#     'risefall': '2',
#     'changeVal': 165,
#     'changeRate': 1.33,
#     'nav': None,
#     'threeMonthEarnRate': 15.6293,
#     'quant': 322956,
#     'amonut': 4033,
#     'marketSum': 1953},
#    {'itemcode': '326240',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR IT플러스',
#     'nowVal': 20780,
#     'risefall': '2',
#     'changeVal': 300,
#     'changeRate': 1.46,
#     'nav': 20777.0,
#     'threeMonthEarnRate': -10.7197,
#     'quant': 211552,
#     'amonut': 4391,
#     'marketSum': 1920},
#    {'itemcode': '272580',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기채권액티브',
#     'nowVal': 50200,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 50195.0,
#     'threeMonthEarnRate': 0.2196,
#     'quant': 2978,
#     'amonut': 149,
#     'marketSum': 1920},
#    {'itemcode': '390950',
#     'etfTabCode': 6,
#     'itemname': 'HANARO 단기채권액티브',
#     'nowVal': 100200,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 100201.0,
#     'threeMonthEarnRate': 0.1249,
#     'quant': 13,
#     'amonut': 1,
#     'marketSum': 1747},
#    {'itemcode': '302450',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스피',
#     'nowVal': 30345,
#     'risefall': '2',
#     'changeVal': 345,
#     'changeRate': 1.15,
#     'nav': 30348.0,
#     'threeMonthEarnRate': -8.1707,
#     'quant': 1407,
#     'amonut': 42,
#     'marketSum': 1714},
#    {'itemcode': '182480',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#     'nowVal': 15255,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.63,
#     'nav': None,
#     'threeMonthEarnRate': 1.6525,
#     'quant': 26596,
#     'amonut': 406,
#     'marketSum': 1678},
#    {'itemcode': '278240',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150선물레버리지',
#     'nowVal': 15305,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.56,
#     'nav': 15311.0,
#     'threeMonthEarnRate': -6.4201,
#     'quant': 5242,
#     'amonut': 79,
#     'marketSum': 1602},
#    {'itemcode': '232080',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150',
#     'nowVal': 14615,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.31,
#     'nav': 14737.0,
#     'threeMonthEarnRate': -3.4039,
#     'quant': 91531,
#     'amonut': 1335,
#     'marketSum': 1593},
#    {'itemcode': '372330',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나항셍테크',
#     'nowVal': 8305,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.78,
#     'nav': None,
#     'threeMonthEarnRate': -15.4277,
#     'quant': 208413,
#     'amonut': 1727,
#     'marketSum': 1586},
#    {'itemcode': '270810',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150',
#     'nowVal': 14320,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.25,
#     'nav': 14453.0,
#     'threeMonthEarnRate': -3.0796,
#     'quant': 13004,
#     'amonut': 185,
#     'marketSum': 1578},
#    {'itemcode': '143860',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 헬스케어',
#     'nowVal': 38465,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.05,
#     'nav': 38597.0,
#     'threeMonthEarnRate': -13.4354,
#     'quant': 35602,
#     'amonut': 1368,
#     'marketSum': 1554},
#    {'itemcode': '148070',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 국고채10년',
#     'nowVal': 118145,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.03,
#     'nav': 118120.0,
#     'threeMonthEarnRate': -2.4482,
#     'quant': 2526,
#     'amonut': 298,
#     'marketSum': 1524},
#    {'itemcode': '379810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100TR',
#     'nowVal': 11730,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 1.03,
#     'nav': None,
#     'threeMonthEarnRate': 4.6387,
#     'quant': 415196,
#     'amonut': 4871,
#     'marketSum': 1513},
#    {'itemcode': '150460',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 중국소비테마',
#     'nowVal': 8695,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.99,
#     'nav': 8702.0,
#     'threeMonthEarnRate': -5.643,
#     'quant': 17975,
#     'amonut': 155,
#     'marketSum': 1484},
#    {'itemcode': '385560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS국고채30년Enhanced',
#     'nowVal': 99235,
#     'risefall': '5',
#     'changeVal': -655,
#     'changeRate': -0.66,
#     'nav': 99031.0,
#     'threeMonthEarnRate': -5.0265,
#     'quant': 117,
#     'amonut': 11,
#     'marketSum': 1469},
#    {'itemcode': '379800',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500TR',
#     'nowVal': 11590,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 1.09,
#     'nav': None,
#     'threeMonthEarnRate': 5.6036,
#     'quant': 196195,
#     'amonut': 2271,
#     'marketSum': 1460},
#    {'itemcode': '325020',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 배당가치',
#     'nowVal': 13175,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 1.0,
#     'nav': 13165.0,
#     'threeMonthEarnRate': -4.321,
#     'quant': 3042,
#     'amonut': 40,
#     'marketSum': 1410},
#    {'itemcode': '394660',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#     'nowVal': 10895,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 1.02,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 221069,
#     'amonut': 2403,
#     'marketSum': 1386},
#    {'itemcode': '368590',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국나스닥100',
#     'nowVal': 13290,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 1.22,
#     'nav': None,
#     'threeMonthEarnRate': 4.6456,
#     'quant': 67425,
#     'amonut': 896,
#     'marketSum': 1369},
#    {'itemcode': '138540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 현대차그룹+펀더멘털',
#     'nowVal': 25505,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.1,
#     'nav': 25504.0,
#     'threeMonthEarnRate': -8.1398,
#     'quant': 24549,
#     'amonut': 626,
#     'marketSum': 1357},
#    {'itemcode': '136340',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 중기우량회사채',
#     'nowVal': 104395,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.04,
#     'nav': 104438.0,
#     'threeMonthEarnRate': -0.472,
#     'quant': 624,
#     'amonut': 65,
#     'marketSum': 1347},
#    {'itemcode': '267770',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물레버리지',
#     'nowVal': 17720,
#     'risefall': '2',
#     'changeVal': 375,
#     'changeRate': 2.16,
#     'nav': 17786.0,
#     'threeMonthEarnRate': -18.9943,
#     'quant': 352693,
#     'amonut': 6243,
#     'marketSum': 1329},
#    {'itemcode': '219480',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500선물(H)',
#     'nowVal': 21440,
#     'risefall': '2',
#     'changeVal': 310,
#     'changeRate': 1.47,
#     'nav': None,
#     'threeMonthEarnRate': 2.0952,
#     'quant': 42907,
#     'amonut': 919,
#     'marketSum': 1319},
#    {'itemcode': '329750',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'nowVal': 10115,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.39,
#     'nav': None,
#     'threeMonthEarnRate': 3.4782,
#     'quant': 162079,
#     'amonut': 1640,
#     'marketSum': 1315},
#    {'itemcode': '252710',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물인버스2X',
#     'nowVal': 2340,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -2.09,
#     'nav': 2328.0,
#     'threeMonthEarnRate': 20.9302,
#     'quant': 6745079,
#     'amonut': 15783,
#     'marketSum': 1280},
#    {'itemcode': '091230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 반도체',
#     'nowVal': 33245,
#     'risefall': '2',
#     'changeVal': 795,
#     'changeRate': 2.45,
#     'nav': 33235.0,
#     'threeMonthEarnRate': -15.5897,
#     'quant': 53347,
#     'amonut': 1769,
#     'marketSum': 1263},
#    {'itemcode': '228800',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 여행레저',
#     'nowVal': 5760,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.7,
#     'nav': 5769.0,
#     'threeMonthEarnRate': 7.2625,
#     'quant': 821256,
#     'amonut': 4734,
#     'marketSum': 1246},
#    {'itemcode': '395750',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG가치주액티브',
#     'nowVal': 9405,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.53,
#     'nav': 9433.0,
#     'threeMonthEarnRate': None,
#     'quant': 8590,
#     'amonut': 80,
#     'marketSum': 1213},
#    {'itemcode': '322400',
#     'etfTabCode': 2,
#     'itemname': 'HANARO e커머스',
#     'nowVal': 18510,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 0.71,
#     'nav': 18506.0,
#     'threeMonthEarnRate': -11.4778,
#     'quant': 39177,
#     'amonut': 724,
#     'marketSum': 1203},
#    {'itemcode': '204480',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#     'nowVal': 32140,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.09,
#     'nav': None,
#     'threeMonthEarnRate': -2.3991,
#     'quant': 29228,
#     'amonut': 935,
#     'marketSum': 1189},
#    {'itemcode': '273140',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'nowVal': 102845,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.02,
#     'nav': 102841.0,
#     'threeMonthEarnRate': 0.2339,
#     'quant': 3,
#     'amonut': 0,
#     'marketSum': 1143},
#    {'itemcode': '283580',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나CSI300',
#     'nowVal': 14590,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.07,
#     'nav': None,
#     'threeMonthEarnRate': 0.0685,
#     'quant': 20351,
#     'amonut': 296,
#     'marketSum': 1138},
#    {'itemcode': '367760',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn5G테크',
#     'nowVal': 9860,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.97,
#     'nav': 9861.0,
#     'threeMonthEarnRate': -14.5581,
#     'quant': 53884,
#     'amonut': 530,
#     'marketSum': 1129},
#    {'itemcode': '309230',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX 미국WideMoat가치주',
#     'nowVal': 18075,
#     'risefall': '2',
#     'changeVal': 195,
#     'changeRate': 1.09,
#     'nav': None,
#     'threeMonthEarnRate': 5.4858,
#     'quant': 85581,
#     'amonut': 1543,
#     'marketSum': 1121},
#    {'itemcode': '298770',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 한국대만IT프리미어',
#     'nowVal': 19045,
#     'risefall': '2',
#     'changeVal': 280,
#     'changeRate': 1.49,
#     'nav': None,
#     'threeMonthEarnRate': -8.3053,
#     'quant': 10580,
#     'amonut': 201,
#     'marketSum': 1105},
#    {'itemcode': '261240',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물',
#     'nowVal': 10450,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.38,
#     'nav': 10465.0,
#     'threeMonthEarnRate': 3.3119,
#     'quant': 444289,
#     'amonut': 4646,
#     'marketSum': 1090},
#    {'itemcode': '139220',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 건설',
#     'nowVal': 3260,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.77,
#     'nav': 3269.0,
#     'threeMonthEarnRate': -5.0947,
#     'quant': 512845,
#     'amonut': 1668,
#     'marketSum': 1071},
#    {'itemcode': '328370',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스피TR',
#     'nowVal': 15220,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 0.89,
#     'nav': 15221.0,
#     'threeMonthEarnRate': -7.4491,
#     'quant': 17232,
#     'amonut': 261,
#     'marketSum': 1065},
#    {'itemcode': '325010',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Fn성장',
#     'nowVal': 17345,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 0.93,
#     'nav': 17334.0,
#     'threeMonthEarnRate': -9.638,
#     'quant': 29926,
#     'amonut': 518,
#     'marketSum': 1041},
#    {'itemcode': '114260',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채3년',
#     'nowVal': 57455,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.03,
#     'nav': 57497.0,
#     'threeMonthEarnRate': -0.5797,
#     'quant': 824,
#     'amonut': 47,
#     'marketSum': 1034},
#    {'itemcode': '144600',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 은선물(H)',
#     'nowVal': 4825,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 1.47,
#     'nav': None,
#     'threeMonthEarnRate': -11.3052,
#     'quant': 388631,
#     'amonut': 1874,
#     'marketSum': 1028},
#    {'itemcode': '329200',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 부동산인프라고배당',
#     'nowVal': 5915,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.25,
#     'nav': 5936.0,
#     'threeMonthEarnRate': 1.6323,
#     'quant': 122121,
#     'amonut': 721,
#     'marketSum': 1014},
#    {'itemcode': '157490',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 소프트웨어',
#     'nowVal': 16580,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 0.91,
#     'nav': 16610.0,
#     'threeMonthEarnRate': -16.178,
#     'quant': 106829,
#     'amonut': 1768,
#     'marketSum': 975},
#    {'itemcode': '329650',
#     'etfTabCode': 7,
#     'itemname': 'KODEX TRF3070',
#     'nowVal': 11370,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.49,
#     'nav': 11317.0,
#     'threeMonthEarnRate': 0.5305,
#     'quant': 61479,
#     'amonut': 698,
#     'marketSum': 966},
#    {'itemcode': '139280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 경기방어',
#     'nowVal': 11425,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.62,
#     'nav': 11424.0,
#     'threeMonthEarnRate': -9.6838,
#     'quant': 10565,
#     'amonut': 120,
#     'marketSum': 935},
#    {'itemcode': '225040',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#     'nowVal': 33565,
#     'risefall': '2',
#     'changeVal': 1005,
#     'changeRate': 3.09,
#     'nav': None,
#     'threeMonthEarnRate': 2.8181,
#     'quant': 26169,
#     'amonut': 875,
#     'marketSum': 906},
#    {'itemcode': '122260',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 통안채1년',
#     'nowVal': 101280,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 101284.0,
#     'threeMonthEarnRate': 0.1087,
#     'quant': 38199,
#     'amonut': 3868,
#     'marketSum': 901},
#    {'itemcode': '117700',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 건설',
#     'nowVal': 3710,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 1.64,
#     'nav': 3713.0,
#     'threeMonthEarnRate': -6.076,
#     'quant': 192882,
#     'amonut': 711,
#     'marketSum': 894},
#    {'itemcode': '364970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX바이오K-뉴딜',
#     'nowVal': 8910,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.28,
#     'nav': 8908.0,
#     'threeMonthEarnRate': -16.2201,
#     'quant': 302812,
#     'amonut': 2689,
#     'marketSum': 887},
#    {'itemcode': '371470',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#     'nowVal': 11325,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.79,
#     'nav': None,
#     'threeMonthEarnRate': -14.0092,
#     'quant': 48134,
#     'amonut': 545,
#     'marketSum': 879},
#    {'itemcode': '174360',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 중국본토대형주CSI100',
#     'nowVal': 21780,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.25,
#     'nav': None,
#     'threeMonthEarnRate': 0.0,
#     'quant': 6384,
#     'amonut': 138,
#     'marketSum': 849},
#    {'itemcode': '306520',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 200선물인버스',
#     'nowVal': 9375,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -1.0,
#     'nav': 9358.0,
#     'threeMonthEarnRate': 10.0352,
#     'quant': 11493,
#     'amonut': 107,
#     'marketSum': 839},
#    {'itemcode': '304940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100선물(H)',
#     'nowVal': 19140,
#     'risefall': '2',
#     'changeVal': 270,
#     'changeRate': 1.43,
#     'nav': None,
#     'threeMonthEarnRate': 1.0292,
#     'quant': 64298,
#     'amonut': 1231,
#     'marketSum': 833},
#    {'itemcode': '387270',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌BBIG액티브',
#     'nowVal': 11815,
#     'risefall': '2',
#     'changeVal': 165,
#     'changeRate': 1.42,
#     'nav': None,
#     'threeMonthEarnRate': 3.5949,
#     'quant': 91885,
#     'amonut': 1080,
#     'marketSum': 821},
#    {'itemcode': '195930',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 유로스탁스50(합성 H)',
#     'nowVal': 14170,
#     'risefall': '2',
#     'changeVal': 190,
#     'changeRate': 1.36,
#     'nav': None,
#     'threeMonthEarnRate': 2.0525,
#     'quant': 42459,
#     'amonut': 601,
#     'marketSum': 808},
#    {'itemcode': '266160',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 고배당',
#     'nowVal': 12550,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 1.01,
#     'nav': 12549.0,
#     'threeMonthEarnRate': -2.4486,
#     'quant': 17807,
#     'amonut': 223,
#     'marketSum': 778},
#    {'itemcode': '195980',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#     'nowVal': 12290,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 1.07,
#     'nav': None,
#     'threeMonthEarnRate': -5.0232,
#     'quant': 24291,
#     'amonut': 297,
#     'marketSum': 764},
#    {'itemcode': '376410',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 탄소효율그린뉴딜',
#     'nowVal': 9620,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.84,
#     'nav': 9622.0,
#     'threeMonthEarnRate': -8.381,
#     'quant': 17706,
#     'amonut': 169,
#     'marketSum': 731},
#    {'itemcode': '387280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 퓨처모빌리티액티브',
#     'nowVal': 11530,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.56,
#     'nav': 11579.0,
#     'threeMonthEarnRate': 2.4888,
#     'quant': 37309,
#     'amonut': 431,
#     'marketSum': 721},
#    {'itemcode': '385520',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-미래차액티브',
#     'nowVal': 10975,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.27,
#     'nav': 10975.0,
#     'threeMonthEarnRate': -0.8134,
#     'quant': 70081,
#     'amonut': 767,
#     'marketSum': 702},
#    {'itemcode': '245340',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국다우존스30',
#     'nowVal': 21010,
#     'risefall': '2',
#     'changeVal': 250,
#     'changeRate': 1.2,
#     'nav': None,
#     'threeMonthEarnRate': 4.3975,
#     'quant': 12517,
#     'amonut': 262,
#     'marketSum': 693},
#    {'itemcode': '256750',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나심천ChiNext(합성)',
#     'nowVal': 14735,
#     'risefall': '2',
#     'changeVal': 235,
#     'changeRate': 1.62,
#     'nav': None,
#     'threeMonthEarnRate': -3.0274,
#     'quant': 17781,
#     'amonut': 258,
#     'marketSum': 693},
#    {'itemcode': '114820',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채3년',
#     'nowVal': 109335,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.01,
#     'nav': 109419.0,
#     'threeMonthEarnRate': -0.5513,
#     'quant': 1454,
#     'amonut': 158,
#     'marketSum': 689},
#    {'itemcode': '123310',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 인버스',
#     'nowVal': 4510,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.99,
#     'nav': 4503.0,
#     'threeMonthEarnRate': 10.2689,
#     'quant': 370953,
#     'amonut': 1673,
#     'marketSum': 686},
#    {'itemcode': '305080',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국채10년선물',
#     'nowVal': 12065,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.21,
#     'nav': None,
#     'threeMonthEarnRate': 2.4628,
#     'quant': 22099,
#     'amonut': 266,
#     'marketSum': 676},
#    {'itemcode': '130730',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 단기자금',
#     'nowVal': 101270,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 101271.0,
#     'threeMonthEarnRate': 0.1532,
#     'quant': 83218,
#     'amonut': 8427,
#     'marketSum': 666},
#    {'itemcode': '130680',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 원유선물Enhanced(H)',
#     'nowVal': 3780,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 1.2,
#     'nav': None,
#     'threeMonthEarnRate': 15.4198,
#     'quant': 309977,
#     'amonut': 1167,
#     'marketSum': 663},
#    {'itemcode': '277630',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스피',
#     'nowVal': 30645,
#     'risefall': '2',
#     'changeVal': 305,
#     'changeRate': 1.01,
#     'nav': 30698.0,
#     'threeMonthEarnRate': -7.8069,
#     'quant': 92132,
#     'amonut': 2820,
#     'marketSum': 659},
#    {'itemcode': '233160',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150 레버리지',
#     'nowVal': 15865,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.41,
#     'nav': 16007.0,
#     'threeMonthEarnRate': -7.2494,
#     'quant': 148086,
#     'amonut': 2338,
#     'marketSum': 643},
#    {'itemcode': '385510',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-신재생에너지액티브',
#     'nowVal': 12475,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': 12472.0,
#     'threeMonthEarnRate': 15.2957,
#     'quant': 119248,
#     'amonut': 1485,
#     'marketSum': 642},
#    {'itemcode': '245360',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나HSCEI',
#     'nowVal': 11240,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.09,
#     'nav': None,
#     'threeMonthEarnRate': -8.7292,
#     'quant': 30186,
#     'amonut': 338,
#     'marketSum': 641},
#    {'itemcode': '228810',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 미디어컨텐츠',
#     'nowVal': 9240,
#     'risefall': '2',
#     'changeVal': 155,
#     'changeRate': 1.71,
#     'nav': 9243.0,
#     'threeMonthEarnRate': 7.8179,
#     'quant': 1035820,
#     'amonut': 9517,
#     'marketSum': 638},
#    {'itemcode': '363510',
#     'etfTabCode': 6,
#     'itemname': 'SOL KIS단기통안채',
#     'nowVal': 100445,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100465.0,
#     'threeMonthEarnRate': 0.1046,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 632},
#    {'itemcode': '365000',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX인터넷K-뉴딜',
#     'nowVal': 11675,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.04,
#     'nav': 11728.0,
#     'threeMonthEarnRate': -12.1851,
#     'quant': 143981,
#     'amonut': 1685,
#     'marketSum': 630},
#    {'itemcode': '368190',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn K-뉴딜디지털플러스',
#     'nowVal': 12235,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.33,
#     'nav': 12239.0,
#     'threeMonthEarnRate': -11.2442,
#     'quant': 8147,
#     'amonut': 99,
#     'marketSum': 630},
#    {'itemcode': '395760',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG성장주액티브',
#     'nowVal': 9440,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 1.12,
#     'nav': 9465.0,
#     'threeMonthEarnRate': None,
#     'quant': 118,
#     'amonut': 1,
#     'marketSum': 628},
#    {'itemcode': '396510',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나클린에너지SOLACTIVE',
#     'nowVal': 10590,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 1.29,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 90892,
#     'amonut': 957,
#     'marketSum': 618},
#    {'itemcode': '397410',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물5년추종인버스',
#     'nowVal': 51015,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.03,
#     'nav': 51008.0,
#     'threeMonthEarnRate': None,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 615},
#    {'itemcode': '302190',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 중장기국채',
#     'nowVal': 51530,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.02,
#     'nav': 51554.0,
#     'threeMonthEarnRate': -1.4252,
#     'quant': 46,
#     'amonut': 2,
#     'marketSum': 587},
#    {'itemcode': '102970',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 증권',
#     'nowVal': 7930,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.89,
#     'nav': 7944.0,
#     'threeMonthEarnRate': -5.987,
#     'quant': 110223,
#     'amonut': 871,
#     'marketSum': 575},
#    {'itemcode': '315960',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 대형고배당10TR',
#     'nowVal': 15490,
#     'risefall': '2',
#     'changeVal': 235,
#     'changeRate': 1.54,
#     'nav': 15491.0,
#     'threeMonthEarnRate': -9.0162,
#     'quant': 6910,
#     'amonut': 106,
#     'marketSum': 550},
#    {'itemcode': '219390',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국S&P원유생산기업(합성 H)',
#     'nowVal': 4745,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 1.61,
#     'nav': None,
#     'threeMonthEarnRate': 20.4314,
#     'quant': 350949,
#     'amonut': 1658,
#     'marketSum': 546},
#    {'itemcode': '354350',
#     'etfTabCode': 4,
#     'itemname': 'HANARO 글로벌럭셔리S&P(합성)',
#     'nowVal': 18240,
#     'risefall': '2',
#     'changeVal': 200,
#     'changeRate': 1.11,
#     'nav': None,
#     'threeMonthEarnRate': 0.2748,
#     'quant': 37682,
#     'amonut': 686,
#     'marketSum': 538},
#    {'itemcode': '200250',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 인도Nifty50(합성)',
#     'nowVal': 19785,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.28,
#     'nav': None,
#     'threeMonthEarnRate': 19.4746,
#     'quant': 56777,
#     'amonut': 1125,
#     'marketSum': 534},
#    {'itemcode': '282000',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 국고채3년선물인버스',
#     'nowVal': 100880,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.04,
#     'nav': 100864.0,
#     'threeMonthEarnRate': 0.7188,
#     'quant': 9,
#     'amonut': 0,
#     'marketSum': 534},
#    {'itemcode': '371450',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌클라우드컴퓨팅INDXX',
#     'nowVal': 12895,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 1.18,
#     'nav': None,
#     'threeMonthEarnRate': 12.7185,
#     'quant': 36295,
#     'amonut': 467,
#     'marketSum': 531},
#    {'itemcode': '117680',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 철강',
#     'nowVal': 9725,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.57,
#     'nav': 9743.0,
#     'threeMonthEarnRate': -5.4908,
#     'quant': 186015,
#     'amonut': 1807,
#     'marketSum': 531},
#    {'itemcode': '363580',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200IT TR',
#     'nowVal': 12885,
#     'risefall': '2',
#     'changeVal': 355,
#     'changeRate': 2.83,
#     'nav': 12882.0,
#     'threeMonthEarnRate': -12.7033,
#     'quant': 2318,
#     'amonut': 29,
#     'marketSum': 528},
#    {'itemcode': '289260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER MSCI KOREA ESG리더스',
#     'nowVal': 11335,
#     'risefall': '2',
#     'changeVal': 195,
#     'changeRate': 1.75,
#     'nav': 11341.0,
#     'threeMonthEarnRate': -8.9559,
#     'quant': 491,
#     'amonut': 5,
#     'marketSum': 527},
#    {'itemcode': '266360',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 미디어&엔터테인먼트',
#     'nowVal': 23805,
#     'risefall': '2',
#     'changeVal': 225,
#     'changeRate': 0.95,
#     'nav': 23869.0,
#     'threeMonthEarnRate': -11.6042,
#     'quant': 27005,
#     'amonut': 642,
#     'marketSum': 524},
#    {'itemcode': '337160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200ESG',
#     'nowVal': 14060,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 1.33,
#     'nav': 14056.0,
#     'threeMonthEarnRate': -9.9296,
#     'quant': 2695,
#     'amonut': 37,
#     'marketSum': 520},
#    {'itemcode': '139230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 중공업',
#     'nowVal': 3395,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 2.41,
#     'nav': 3386.0,
#     'threeMonthEarnRate': -12.3871,
#     'quant': 341480,
#     'amonut': 1152,
#     'marketSum': 504},
#    {'itemcode': '336160',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 금융채액티브',
#     'nowVal': 102305,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 102348.0,
#     'threeMonthEarnRate': -0.4283,
#     'quant': 94,
#     'amonut': 9,
#     'marketSum': 501},
#    {'itemcode': '099140',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나H',
#     'nowVal': 19085,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.13,
#     'nav': None,
#     'threeMonthEarnRate': -9.1624,
#     'quant': 19761,
#     'amonut': 376,
#     'marketSum': 496},
#    {'itemcode': '256440',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 인도네시아MSCI(합성)',
#     'nowVal': 9725,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.67,
#     'nav': None,
#     'threeMonthEarnRate': 25.2414,
#     'quant': 127869,
#     'amonut': 1243,
#     'marketSum': 496},
#    {'itemcode': '379780',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국S&P500',
#     'nowVal': 11505,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 1.14,
#     'nav': None,
#     'threeMonthEarnRate': 5.4054,
#     'quant': 27504,
#     'amonut': 316,
#     'marketSum': 495},
#    {'itemcode': '304780',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200선물레버리지',
#     'nowVal': 25710,
#     'risefall': '2',
#     'changeVal': 570,
#     'changeRate': 2.27,
#     'nav': 25807.0,
#     'threeMonthEarnRate': -19.0237,
#     'quant': 6708,
#     'amonut': 172,
#     'marketSum': 488},
#    {'itemcode': '388280',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn컨택트대표',
#     'nowVal': 10120,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 1.2,
#     'nav': 10148.0,
#     'threeMonthEarnRate': 2.1706,
#     'quant': 151278,
#     'amonut': 1527,
#     'marketSum': 470},
#    {'itemcode': '266370',
#     'etfTabCode': 2,
#     'itemname': 'KODEX IT',
#     'nowVal': 19295,
#     'risefall': '2',
#     'changeVal': 465,
#     'changeRate': 2.47,
#     'nav': 19297.0,
#     'threeMonthEarnRate': -10.5264,
#     'quant': 15148,
#     'amonut': 291,
#     'marketSum': 463},
#    {'itemcode': '375770',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 탄소효율그린뉴딜',
#     'nowVal': 9610,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 1.26,
#     'nav': 9610.0,
#     'threeMonthEarnRate': -8.3016,
#     'quant': 7697,
#     'amonut': 73,
#     'marketSum': 461},
#    {'itemcode': '292190',
#     'etfTabCode': 1,
#     'itemname': 'KODEX KRX300',
#     'nowVal': 18270,
#     'risefall': '2',
#     'changeVal': 210,
#     'changeRate': 1.16,
#     'nav': 18271.0,
#     'threeMonthEarnRate': -8.9687,
#     'quant': 5914,
#     'amonut': 107,
#     'marketSum': 457},
#    {'itemcode': '114460',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국고채3년',
#     'nowVal': 105505,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.08,
#     'nav': 105525.0,
#     'threeMonthEarnRate': -0.4867,
#     'quant': 16,
#     'amonut': 1,
#     'marketSum': 443},
#    {'itemcode': '228790',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 화장품',
#     'nowVal': 3275,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 2.02,
#     'nav': 3272.0,
#     'threeMonthEarnRate': -16.7726,
#     'quant': 713149,
#     'amonut': 2312,
#     'marketSum': 443},
#    {'itemcode': '356540',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX KIS종합채권(AA-이상)액티브',
#     'nowVal': 97385,
#     'risefall': '2',
# ...
#     'itemname': 'KBSTAR 200고배당커버드콜ATM',
#     'nowVal': 8460,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.77,
#     'nav': 8439.0,
#     'threeMonthEarnRate': 1.9277,
#     'quant': 20,
#     'amonut': 0,
#     'marketSum': 59},
#    {'itemcode': '261920',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 필리핀MSCI(합성)',
#     'nowVal': 14800,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.24,
#     'nav': None,
#     'threeMonthEarnRate': 12.2487,
#     'quant': 430,
#     'amonut': 6,
#     'marketSum': 59},
#    {'itemcode': '253280',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 헬스케어',
#     'nowVal': 14710,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.07,
#     'nav': 14709.0,
#     'threeMonthEarnRate': -11.3054,
#     'quant': 611,
#     'amonut': 8,
#     'marketSum': 59},
#    {'itemcode': '342620',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KRX국채선물3년10년플래트너2X',
#     'nowVal': 49040,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.14,
#     'nav': 49019.0,
#     'threeMonthEarnRate': -0.2442,
#     'quant': 7,
#     'amonut': 0,
#     'marketSum': 59},
#    {'itemcode': '292340',
#     'etfTabCode': 2,
#     'itemname': '마이티 200커버드콜ATM레버리지',
#     'nowVal': 9775,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 9921.0,
#     'threeMonthEarnRate': -12.4337,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 59},
#    {'itemcode': '261270',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물인버스',
#     'nowVal': 9680,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.26,
#     'nav': 9686.0,
#     'threeMonthEarnRate': -3.4896,
#     'quant': 29650,
#     'amonut': 286,
#     'marketSum': 58},
#    {'itemcode': '315480',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200커뮤니케이션서비스',
#     'nowVal': 19360,
#     'risefall': '2',
#     'changeVal': 165,
#     'changeRate': 0.86,
#     'nav': 19326.0,
#     'threeMonthEarnRate': -13.9556,
#     'quant': 111,
#     'amonut': 2,
#     'marketSum': 58},
#    {'itemcode': '267440',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물(H)',
#     'nowVal': 11590,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.52,
#     'nav': None,
#     'threeMonthEarnRate': -1.0248,
#     'quant': 358,
#     'amonut': 4,
#     'marketSum': 58},
#    {'itemcode': '281990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 중소형고배당',
#     'nowVal': 12740,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.91,
#     'nav': 12738.0,
#     'threeMonthEarnRate': -0.0393,
#     'quant': 6517,
#     'amonut': 82,
#     'marketSum': 57},
#    {'itemcode': '346000',
#     'etfTabCode': 6,
#     'itemname': 'HANARO KAP초장기국고채',
#     'nowVal': 45050,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.07,
#     'nav': 45017.0,
#     'threeMonthEarnRate': -2.7124,
#     'quant': 215,
#     'amonut': 9,
#     'marketSum': 55},
#    {'itemcode': '321410',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 멀티에셋하이인컴(H)',
#     'nowVal': 10910,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.46,
#     'nav': None,
#     'threeMonthEarnRate': -0.0916,
#     'quant': 642,
#     'amonut': 7,
#     'marketSum': 55},
#    {'itemcode': '098560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 방송통신',
#     'nowVal': 10065,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.55,
#     'nav': 10063.0,
#     'threeMonthEarnRate': -3.3606,
#     'quant': 1591,
#     'amonut': 15,
#     'marketSum': 54},
#    {'itemcode': '220130',
#     'etfTabCode': 4,
#     'itemname': 'SOL 중국본토 중소형 CSI500(합성 H)',
#     'nowVal': 6000,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.5,
#     'nav': None,
#     'threeMonthEarnRate': 3.1814,
#     'quant': 941,
#     'amonut': 5,
#     'marketSum': 54},
#    {'itemcode': '139310',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 금속선물(H)',
#     'nowVal': 7705,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 1.25,
#     'nav': None,
#     'threeMonthEarnRate': 11.7476,
#     'quant': 11256,
#     'amonut': 86,
#     'marketSum': 54},
#    {'itemcode': '295820',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200동일가중',
#     'nowVal': 11795,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.98,
#     'nav': 11782.0,
#     'threeMonthEarnRate': -4.1447,
#     'quant': 368,
#     'amonut': 4,
#     'marketSum': 53},
#    {'itemcode': '291890',
#     'etfTabCode': 4,
#     'itemname': 'KODEX MSCI EM선물(H)',
#     'nowVal': 10320,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.73,
#     'nav': None,
#     'threeMonthEarnRate': -4.4445,
#     'quant': 413,
#     'amonut': 4,
#     'marketSum': 52},
#    {'itemcode': '147970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 모멘텀',
#     'nowVal': 25795,
#     'risefall': '2',
#     'changeVal': 265,
#     'changeRate': 1.04,
#     'nav': 25771.0,
#     'threeMonthEarnRate': -1.5459,
#     'quant': 100,
#     'amonut': 2,
#     'marketSum': 52},
#    {'itemcode': '292770',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국채선물3년인버스',
#     'nowVal': 50335,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 50288.0,
#     'threeMonthEarnRate': 0.7007,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 51},
#    {'itemcode': '299080',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물3년인버스',
#     'nowVal': 100700,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100607.0,
#     'threeMonthEarnRate': 0.7861,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 50},
#    {'itemcode': '291680',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 차이나H선물인버스(H)',
#     'nowVal': 10925,
#     'risefall': '5',
#     'changeVal': -220,
#     'changeRate': -1.97,
#     'nav': None,
#     'threeMonthEarnRate': 11.3659,
#     'quant': 3625,
#     'amonut': 39,
#     'marketSum': 49},
#    {'itemcode': '334690',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물(H)',
#     'nowVal': 12285,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.16,
#     'nav': None,
#     'threeMonthEarnRate': -23.9555,
#     'quant': 7863,
#     'amonut': 96,
#     'marketSum': 49},
#    {'itemcode': '371870',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 차이나항셍테크',
#     'nowVal': 8180,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.73,
#     'nav': None,
#     'threeMonthEarnRate': -15.321,
#     'quant': 5036,
#     'amonut': 40,
#     'marketSum': 49},
#    {'itemcode': '299070',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물10년인버스',
#     'nowVal': 97865,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 97766.0,
#     'threeMonthEarnRate': 3.1694,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 49},
#    {'itemcode': '285010',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200중공업',
#     'nowVal': 10505,
#     'risefall': '2',
#     'changeVal': 235,
#     'changeRate': 2.29,
#     'nav': 10501.0,
#     'threeMonthEarnRate': -12.0921,
#     'quant': 6417,
#     'amonut': 67,
#     'marketSum': 48},
#    {'itemcode': '275750',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150선물인버스',
#     'nowVal': 4595,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.22,
#     'nav': 4586.0,
#     'threeMonthEarnRate': 1.6592,
#     'quant': 18041,
#     'amonut': 82,
#     'marketSum': 48},
#    {'itemcode': '301410',
#     'etfTabCode': 3,
#     'itemname': 'ARIRANG 코스닥150선물인버스',
#     'nowVal': 6865,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.65,
#     'nav': 6882.0,
#     'threeMonthEarnRate': 1.3284,
#     'quant': 18930,
#     'amonut': 130,
#     'marketSum': 48},
#    {'itemcode': '333980',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KS퀄리티가중TR',
#     'nowVal': 15460,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 1.05,
#     'nav': 15457.0,
#     'threeMonthEarnRate': -6.3598,
#     'quant': 36,
#     'amonut': 0,
#     'marketSum': 46},
#    {'itemcode': '157500',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 증권',
#     'nowVal': 4660,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 1.53,
#     'nav': 4660.0,
#     'threeMonthEarnRate': -5.6681,
#     'quant': 13326,
#     'amonut': 61,
#     'marketSum': 46},
#    {'itemcode': '280920',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 주도업종',
#     'nowVal': 11370,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.26,
#     'nav': 11366.0,
#     'threeMonthEarnRate': -10.4372,
#     'quant': 20,
#     'amonut': 0,
#     'marketSum': 45},
#    {'itemcode': '287300',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200건설',
#     'nowVal': 13245,
#     'risefall': '2',
#     'changeVal': 175,
#     'changeRate': 1.34,
#     'nav': 13255.0,
#     'threeMonthEarnRate': -4.7465,
#     'quant': 512,
#     'amonut': 6,
#     'marketSum': 45},
#    {'itemcode': '309210',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KRX300헬스케어',
#     'nowVal': 11680,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 11754.0,
#     'threeMonthEarnRate': -13.8326,
#     'quant': 1372,
#     'amonut': 15,
#     'marketSum': 44},
#    {'itemcode': '227550',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 산업재',
#     'nowVal': 6655,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 1.14,
#     'nav': 6651.0,
#     'threeMonthEarnRate': -10.9104,
#     'quant': 10735,
#     'amonut': 71,
#     'marketSum': 44},
#    {'itemcode': '266550',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 중형주저변동50',
#     'nowVal': 12440,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.48,
#     'nav': 12436.0,
#     'threeMonthEarnRate': 2.0927,
#     'quant': 395,
#     'amonut': 4,
#     'marketSum': 44},
#    {'itemcode': '280940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 골드선물인버스(H)',
#     'nowVal': 7250,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.21,
#     'nav': None,
#     'threeMonthEarnRate': 1.6117,
#     'quant': 2104,
#     'amonut': 15,
#     'marketSum': 44},
#    {'itemcode': '253240',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 200선물인버스',
#     'nowVal': 5270,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -1.03,
#     'nav': 5257.0,
#     'threeMonthEarnRate': 9.7916,
#     'quant': 8459,
#     'amonut': 44,
#     'marketSum': 43},
#    {'itemcode': '291620',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물인버스',
#     'nowVal': 7895,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.38,
#     'nav': 7897.0,
#     'threeMonthEarnRate': 1.4129,
#     'quant': 3908,
#     'amonut': 30,
#     'marketSum': 42},
#    {'itemcode': '227560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 생활소비재',
#     'nowVal': 10855,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.93,
#     'nav': 10878.0,
#     'threeMonthEarnRate': -10.1408,
#     'quant': 687,
#     'amonut': 7,
#     'marketSum': 41},
#    {'itemcode': '295020',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년인버스',
#     'nowVal': 48785,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.07,
#     'nav': 48766.0,
#     'threeMonthEarnRate': 2.6512,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 41},
#    {'itemcode': '302170',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채선물3년인버스',
#     'nowVal': 50400,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 50358.0,
#     'threeMonthEarnRate': 0.7199,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 40},
#    {'itemcode': '217790',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 가격조정',
#     'nowVal': 24960,
#     'risefall': '2',
#     'changeVal': 230,
#     'changeRate': 0.93,
#     'nav': 24921.0,
#     'threeMonthEarnRate': -6.8831,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 40},
#    {'itemcode': '267450',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#     'nowVal': 7970,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.37,
#     'nav': None,
#     'threeMonthEarnRate': 0.3778,
#     'quant': 1595,
#     'amonut': 12,
#     'marketSum': 40},
#    {'itemcode': '302180',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채선물10년인버스',
#     'nowVal': 49545,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.15,
#     'nav': 49538.0,
#     'threeMonthEarnRate': 2.8865,
#     'quant': 11,
#     'amonut': 0,
#     'marketSum': 40},
#    {'itemcode': '278420',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG우수기업',
#     'nowVal': 9845,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.87,
#     'nav': 9844.0,
#     'threeMonthEarnRate': -2.3798,
#     'quant': 2581,
#     'amonut': 25,
#     'marketSum': 39},
#    {'itemcode': '217770',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 원유선물인버스(H)',
#     'nowVal': 5005,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -1.28,
#     'nav': None,
#     'threeMonthEarnRate': -15.6698,
#     'quant': 19499,
#     'amonut': 97,
#     'marketSum': 35},
#    {'itemcode': '295000',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년',
#     'nowVal': 54200,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.05,
#     'nav': 54185.0,
#     'threeMonthEarnRate': -2.5881,
#     'quant': 266,
#     'amonut': 14,
#     'marketSum': 35},
#    {'itemcode': '284990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200에너지화학',
#     'nowVal': 14430,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.17,
#     'nav': 14430.0,
#     'threeMonthEarnRate': 2.4494,
#     'quant': 848,
#     'amonut': 12,
#     'marketSum': 35},
#    {'itemcode': '215620',
#     'etfTabCode': 2,
#     'itemname': 'HK S&P코리아로우볼',
#     'nowVal': 12370,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 12543.0,
#     'threeMonthEarnRate': -1.731,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 33},
#    {'itemcode': '267500',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#     'nowVal': 5960,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.17,
#     'nav': None,
#     'threeMonthEarnRate': -2.6144,
#     'quant': 2601,
#     'amonut': 15,
#     'marketSum': 33},
#    {'itemcode': '285020',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200철강소재',
#     'nowVal': 9650,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 1.31,
#     'nav': 9646.0,
#     'threeMonthEarnRate': -1.5809,
#     'quant': 11050,
#     'amonut': 106,
#     'marketSum': 31},
#    {'itemcode': '284980',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200금융',
#     'nowVal': 9040,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 1.4,
#     'nav': 9043.0,
#     'threeMonthEarnRate': 1.6301,
#     'quant': 2521,
#     'amonut': 22,
#     'marketSum': 31},
#    {'itemcode': '301400',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스닥150',
#     'nowVal': 14350,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.28,
#     'nav': 14492.0,
#     'threeMonthEarnRate': -4.3653,
#     'quant': 486,
#     'amonut': 6,
#     'marketSum': 29},
#    {'itemcode': '252720',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀밸류',
#     'nowVal': 14330,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.53,
#     'nav': 14355.0,
#     'threeMonthEarnRate': -7.2192,
#     'quant': 2,
#     'amonut': 0,
#     'marketSum': 29},
#    {'itemcode': '397420',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물5년추종',
#     'nowVal': 49040,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.02,
#     'nav': 49018.0,
#     'threeMonthEarnRate': None,
#     'quant': 3,
#     'amonut': 0,
#     'marketSum': 24},
#    {'itemcode': '334700',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#     'nowVal': 5270,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 1.25,
#     'nav': None,
#     'threeMonthEarnRate': 23.5638,
#     'quant': 3110,
#     'amonut': 16,
#     'marketSum': 21},
#    {'itemcode': '287330',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200생활소비재',
#     'nowVal': 8285,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.91,
#     'nav': 8298.0,
#     'threeMonthEarnRate': -10.0923,
#     'quant': 2404,
#     'amonut': 19,
#     'marketSum': 20},
#    {'itemcode': '287310',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200경기소비재',
#     'nowVal': 11425,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.22,
#     'nav': 11416.0,
#     'threeMonthEarnRate': -6.0058,
#     'quant': 217,
#     'amonut': 2,
#     'marketSum': 16},
#    {'itemcode': '287320',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200산업재',
#     'nowVal': 11900,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.98,
#     'nav': 11893.0,
#     'threeMonthEarnRate': -10.8615,
#     'quant': 56,
#     'amonut': 0,
#     'marketSum': 14}]}}

# %% [markdown]
# ### JSON 에서 원하는 데이터 찾기

# %%
# result > etfItemList 의 하위 구조로 목록을 찾고자 하는 데이터를 가져옵니다.
etfItemList = etf_json ["result"]["etfItemList"]
etfItemList
# Out:
# [{'itemcode': '069500',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 200',
#   'nowVal': 39420,
#   'risefall': '2',
#   'changeVal': 400,
#   'changeRate': 1.03,
#   'nav': 39436.0,
#   'threeMonthEarnRate': -9.668,
#   'quant': 2570170,
#   'amonut': 101274,
#   'marketSum': 48270},
#  {'itemcode': '371460',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나전기차SOLACTIVE',
#   'nowVal': 17850,
#   'risefall': '2',
#   'changeVal': 440,
#   'changeRate': 2.53,
#   'nav': None,
#   'threeMonthEarnRate': 7.2716,
#   'quant': 8417623,
#   'amonut': 148973,
#   'marketSum': 22977},
#  {'itemcode': '102110',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 200',
#   'nowVal': 39460,
#   'risefall': '2',
#   'changeVal': 415,
#   'changeRate': 1.06,
#   'nav': 39472.0,
#   'threeMonthEarnRate': -9.6074,
#   'quant': 430561,
#   'amonut': 16985,
#   'marketSum': 21466},
#  {'itemcode': '153130',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기채권',
#   'nowVal': 102965,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': 0.0,
#   'nav': 102964.0,
#   'threeMonthEarnRate': 0.1215,
#   'quant': 10120,
#   'amonut': 1041,
#   'marketSum': 21277},
#  {'itemcode': '252670',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 200선물인버스2X',
#   'nowVal': 2245,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -2.18,
#   'nav': 2239.0,
#   'threeMonthEarnRate': 20.0534,
#   'quant': 187196187,
#   'amonut': 421296,
#   'marketSum': 19906},
#  {'itemcode': '122630',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 레버리지',
#   'nowVal': 23535,
#   'risefall': '2',
#   'changeVal': 485,
#   'changeRate': 2.1,
#   'nav': 23620.0,
#   'threeMonthEarnRate': -18.7608,
#   'quant': 19143272,
#   'amonut': 449886,
#   'marketSum': 19299},
#  {'itemcode': '214980',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기채권PLUS',
#   'nowVal': 103275,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 103278.0,
#   'threeMonthEarnRate': 0.126,
#   'quant': 2522411,
#   'amonut': 260501,
#   'marketSum': 18504},
#  {'itemcode': '102780',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 삼성그룹',
#   'nowVal': 9840,
#   'risefall': '2',
#   'changeVal': 180,
#   'changeRate': 1.86,
#   'nav': 9864.0,
#   'threeMonthEarnRate': -6.2411,
#   'quant': 414906,
#   'amonut': 4076,
#   'marketSum': 17623},
#  {'itemcode': '157450',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 단기통안채',
#   'nowVal': 100370,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 100367.0,
#   'threeMonthEarnRate': 0.1396,
#   'quant': 30457,
#   'amonut': 3056,
#   'marketSum': 14671},
#  {'itemcode': '273130',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 종합채권(AA-이상)액티브',
#   'nowVal': 107840,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 107801.0,
#   'threeMonthEarnRate': -1.25,
#   'quant': 23285,
#   'amonut': 2509,
#   'marketSum': 14387},
#  {'itemcode': '133690',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국나스닥100',
#   'nowVal': 80005,
#   'risefall': '2',
#   'changeVal': 1000,
#   'changeRate': 1.27,
#   'nav': None,
#   'threeMonthEarnRate': 4.6966,
#   'quant': 108453,
#   'amonut': 8672,
#   'marketSum': 13761},
#  {'itemcode': '292150',
#   'etfTabCode': 2,
#   'itemname': 'TIGER TOP10',
#   'nowVal': 13285,
#   'risefall': '2',
#   'changeVal': 115,
#   'changeRate': 0.87,
#   'nav': 13288.0,
#   'threeMonthEarnRate': -12.1944,
#   'quant': 221712,
#   'amonut': 2942,
#   'marketSum': 12255},
#  {'itemcode': '278530',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 200TR',
#   'nowVal': 12890,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 1.02,
#   'nav': 12913.0,
#   'threeMonthEarnRate': -9.7971,
#   'quant': 76484,
#   'amonut': 986,
#   'marketSum': 11678},
#  {'itemcode': '114800',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 인버스',
#   'nowVal': 4070,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -1.09,
#   'nav': 4065.0,
#   'threeMonthEarnRate': 10.0,
#   'quant': 32468613,
#   'amonut': 132306,
#   'marketSum': 11376},
#  {'itemcode': '305540',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 2차전지테마',
#   'nowVal': 23470,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.06,
#   'nav': 23459.0,
#   'threeMonthEarnRate': 18.0286,
#   'quant': 2035599,
#   'amonut': 47764,
#   'marketSum': 11078},
#  {'itemcode': '305720',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 2차전지산업',
#   'nowVal': 23540,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.02,
#   'nav': 23548.0,
#   'threeMonthEarnRate': 14.9975,
#   'quant': 1427169,
#   'amonut': 33591,
#   'marketSum': 10970},
#  {'itemcode': '148020',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 200',
#   'nowVal': 39500,
#   'risefall': '2',
#   'changeVal': 415,
#   'changeRate': 1.06,
#   'nav': 39526.0,
#   'threeMonthEarnRate': -9.5883,
#   'quant': 151047,
#   'amonut': 5970,
#   'marketSum': 10724},
#  {'itemcode': '278540',
#   'etfTabCode': 1,
#   'itemname': 'KODEX MSCI Korea TR',
#   'nowVal': 12555,
#   'risefall': '2',
#   'changeVal': 140,
#   'changeRate': 1.13,
#   'nav': 12558.0,
#   'threeMonthEarnRate': -10.2253,
#   'quant': 481525,
#   'amonut': 6040,
#   'marketSum': 10107},
#  {'itemcode': '310970',
#   'etfTabCode': 1,
#   'itemname': 'TIGER MSCI Korea TR',
#   'nowVal': 15780,
#   'risefall': '2',
#   'changeVal': 165,
#   'changeRate': 1.06,
#   'nav': 15779.0,
#   'threeMonthEarnRate': -10.5443,
#   'quant': 830,
#   'amonut': 13,
#   'marketSum': 8679},
#  {'itemcode': '139260',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 IT',
#   'nowVal': 34155,
#   'risefall': '2',
#   'changeVal': 930,
#   'changeRate': 2.8,
#   'nav': 34143.0,
#   'threeMonthEarnRate': -13.0474,
#   'quant': 121578,
#   'amonut': 4130,
#   'marketSum': 8593},
#  {'itemcode': '233740',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스닥150 레버리지',
#   'nowVal': 14870,
#   'risefall': '2',
#   'changeVal': 90,
#   'changeRate': 0.61,
#   'nav': 15033.0,
#   'threeMonthEarnRate': -7.4674,
#   'quant': 7626923,
#   'amonut': 112963,
#   'marketSum': 8461},
#  {'itemcode': '381170',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국테크TOP10 INDXX',
#   'nowVal': 11860,
#   'risefall': '2',
#   'changeVal': 150,
#   'changeRate': 1.28,
#   'nav': None,
#   'threeMonthEarnRate': 4.5855,
#   'quant': 969922,
#   'amonut': 11490,
#   'marketSum': 8195},
#  {'itemcode': '091180',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 자동차',
#   'nowVal': 22205,
#   'risefall': '5',
#   'changeVal': -115,
#   'changeRate': -0.52,
#   'nav': 22177.0,
#   'threeMonthEarnRate': -7.7866,
#   'quant': 249293,
#   'amonut': 5529,
#   'marketSum': 7905},
#  {'itemcode': '152100',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 200',
#   'nowVal': 39965,
#   'risefall': '2',
#   'changeVal': 425,
#   'changeRate': 1.07,
#   'nav': 39979.0,
#   'threeMonthEarnRate': -9.3867,
#   'quant': 61819,
#   'amonut': 2472,
#   'marketSum': 7673},
#  {'itemcode': '105190',
#   'etfTabCode': 1,
#   'itemname': 'KINDEX 200',
#   'nowVal': 39580,
#   'risefall': '2',
#   'changeVal': 410,
#   'changeRate': 1.05,
#   'nav': 39590.0,
#   'threeMonthEarnRate': -9.5522,
#   'quant': 438818,
#   'amonut': 17375,
#   'marketSum': 6966},
#  {'itemcode': '394670',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#   'nowVal': 11450,
#   'risefall': '2',
#   'changeVal': 330,
#   'changeRate': 2.97,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 2050621,
#   'amonut': 23263,
#   'marketSum': 6902},
#  {'itemcode': '360750',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500',
#   'nowVal': 13255,
#   'risefall': '2',
#   'changeVal': 145,
#   'changeRate': 1.11,
#   'nav': None,
#   'threeMonthEarnRate': 5.441,
#   'quant': 372103,
#   'amonut': 4929,
#   'marketSum': 6681},
#  {'itemcode': '364980',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX2차전지K-뉴딜',
#   'nowVal': 18240,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.14,
#   'nav': 18294.0,
#   'threeMonthEarnRate': 3.6363,
#   'quant': 1054100,
#   'amonut': 19305,
#   'marketSum': 6265},
#  {'itemcode': '293180',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200',
#   'nowVal': 39475,
#   'risefall': '2',
#   'changeVal': 435,
#   'changeRate': 1.11,
#   'nav': 39469.0,
#   'threeMonthEarnRate': -9.5834,
#   'quant': 12234,
#   'amonut': 483,
#   'marketSum': 5961},
#  {'itemcode': '069660',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 200',
#   'nowVal': 39500,
#   'risefall': '2',
#   'changeVal': 440,
#   'changeRate': 1.13,
#   'nav': 39490.0,
#   'threeMonthEarnRate': -9.6524,
#   'quant': 4124,
#   'amonut': 162,
#   'marketSum': 5589},
#  {'itemcode': '381180',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국필라델피아반도체나스닥',
#   'nowVal': 10540,
#   'risefall': '2',
#   'changeVal': 250,
#   'changeRate': 2.43,
#   'nav': None,
#   'threeMonthEarnRate': 3.6891,
#   'quant': 798699,
#   'amonut': 8406,
#   'marketSum': 5339},
#  {'itemcode': '314250',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국FANG플러스(H)',
#   'nowVal': 28950,
#   'risefall': '2',
#   'changeVal': 285,
#   'changeRate': 0.99,
#   'nav': None,
#   'threeMonthEarnRate': -0.31,
#   'quant': 124232,
#   'amonut': 3584,
#   'marketSum': 4777},
#  {'itemcode': '251340',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 코스닥150선물인버스',
#   'nowVal': 4340,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.23,
#   'nav': 4348.0,
#   'threeMonthEarnRate': 1.5204,
#   'quant': 26365179,
#   'amonut': 114691,
#   'marketSum': 4700},
#  {'itemcode': '315930',
#   'etfTabCode': 2,
#   'itemname': 'KODEX Top5PlusTR',
#   'nowVal': 18000,
#   'risefall': '2',
#   'changeVal': 205,
#   'changeRate': 1.15,
#   'nav': 17985.0,
#   'threeMonthEarnRate': -10.5591,
#   'quant': 3151,
#   'amonut': 56,
#   'marketSum': 4680},
#  {'itemcode': '294400',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 200TR',
#   'nowVal': 46910,
#   'risefall': '2',
#   'changeVal': 445,
#   'changeRate': 0.96,
#   'nav': 46939.0,
#   'threeMonthEarnRate': -9.6843,
#   'quant': 35496,
#   'amonut': 1663,
#   'marketSum': 4644},
#  {'itemcode': '360200',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 미국S&P500',
#   'nowVal': 13350,
#   'risefall': '2',
#   'changeVal': 150,
#   'changeRate': 1.14,
#   'nav': None,
#   'threeMonthEarnRate': 5.5252,
#   'quant': 138662,
#   'amonut': 1850,
#   'marketSum': 3978},
#  {'itemcode': '364960',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX BBIG K-뉴딜',
#   'nowVal': 12305,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.45,
#   'nav': 12309.0,
#   'threeMonthEarnRate': -11.2194,
#   'quant': 157869,
#   'amonut': 1938,
#   'marketSum': 3833},
#  {'itemcode': '385540',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#   'nowVal': 99360,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.04,
#   'nav': 99316.0,
#   'threeMonthEarnRate': -1.1245,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 3798},
#  {'itemcode': '226490',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스피',
#   'nowVal': 30370,
#   'risefall': '2',
#   'changeVal': 350,
#   'changeRate': 1.17,
#   'nav': 30374.0,
#   'threeMonthEarnRate': -8.1368,
#   'quant': 143774,
#   'amonut': 4366,
#   'marketSum': 3675},
#  {'itemcode': '196230',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 단기통안채',
#   'nowVal': 104645,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.01,
#   'nav': 104640.0,
#   'threeMonthEarnRate': 0.1723,
#   'quant': 797949,
#   'amonut': 83493,
#   'marketSum': 3604},
#  {'itemcode': '091170',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 은행',
#   'nowVal': 7440,
#   'risefall': '2',
#   'changeVal': 110,
#   'changeRate': 1.5,
#   'nav': 7461.0,
#   'threeMonthEarnRate': 1.5006,
#   'quant': 787218,
#   'amonut': 5837,
#   'marketSum': 3567},
#  {'itemcode': '229200',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스닥 150',
#   'nowVal': 14380,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.03,
#   'nav': 14525.0,
#   'threeMonthEarnRate': -3.3927,
#   'quant': 1420242,
#   'amonut': 20391,
#   'marketSum': 3494},
#  {'itemcode': '332500',
#   'etfTabCode': 1,
#   'itemname': 'KINDEX 200TR',
#   'nowVal': 24065,
#   'risefall': '2',
#   'changeVal': 235,
#   'changeRate': 0.99,
#   'nav': 24082.0,
#   'threeMonthEarnRate': -9.649,
#   'quant': 5738,
#   'amonut': 138,
#   'marketSum': 3489},
#  {'itemcode': '367770',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR Fn수소경제테마',
#   'nowVal': 12905,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.19,
#   'nav': 12897.0,
#   'threeMonthEarnRate': 0.3109,
#   'quant': 265547,
#   'amonut': 3424,
#   'marketSum': 3375},
#  {'itemcode': '251350',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 선진국MSCI World',
#   'nowVal': 20710,
#   'risefall': '2',
#   'changeVal': 265,
#   'changeRate': 1.3,
#   'nav': None,
#   'threeMonthEarnRate': 5.5555,
#   'quant': 85146,
#   'amonut': 1758,
#   'marketSum': 3355},
#  {'itemcode': '290130',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR ESG사회책임투자',
#   'nowVal': 12695,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 0.99,
#   'nav': 12694.0,
#   'threeMonthEarnRate': -11.0995,
#   'quant': 13975,
#   'amonut': 177,
#   'marketSum': 3301},
#  {'itemcode': '371160',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나항셍테크',
#   'nowVal': 8285,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.66,
#   'nav': None,
#   'threeMonthEarnRate': -15.4161,
#   'quant': 360484,
#   'amonut': 2982,
#   'marketSum': 3231},
#  {'itemcode': '367380',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 미국나스닥100',
#   'nowVal': 13735,
#   'risefall': '2',
#   'changeVal': 155,
#   'changeRate': 1.14,
#   'nav': None,
#   'threeMonthEarnRate': 4.7274,
#   'quant': 115427,
#   'amonut': 1585,
#   'marketSum': 2747},
#  {'itemcode': '272560',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 단기국공채액티브',
#   'nowVal': 102235,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.01,
#   'nav': 102225.0,
#   'threeMonthEarnRate': 0.1812,
#   'quant': 432429,
#   'amonut': 44205,
#   'marketSum': 2618},
#  {'itemcode': '357870',
#   'etfTabCode': 7,
#   'itemname': 'TIGER CD금리투자KIS(합성)',
#   'nowVal': 50465,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.03,
#   'nav': 50445.0,
#   'threeMonthEarnRate': 0.2084,
#   'quant': 4,
#   'amonut': 0,
#   'marketSum': 2576},
#  {'itemcode': '295040',
#   'etfTabCode': 1,
#   'itemname': 'SOL 200TR',
#   'nowVal': 13425,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 0.98,
#   'nav': 13437.0,
#   'threeMonthEarnRate': -9.7176,
#   'quant': 17919,
#   'amonut': 240,
#   'marketSum': 2557},
#  {'itemcode': '332940',
#   'etfTabCode': 1,
#   'itemname': 'HANARO MSCI Korea TR',
#   'nowVal': 15700,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 0.45,
#   'nav': 15761.0,
#   'threeMonthEarnRate': -10.8462,
#   'quant': 50,
#   'amonut': 0,
#   'marketSum': 2543},
#  {'itemcode': '385550',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#   'nowVal': 100125,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 100117.0,
#   'threeMonthEarnRate': 0.18,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 2538},
#  {'itemcode': '192090',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나CSI300',
#   'nowVal': 11995,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.04,
#   'nav': None,
#   'threeMonthEarnRate': -0.3738,
#   'quant': 100220,
#   'amonut': 1202,
#   'marketSum': 2495},
#  {'itemcode': '275980',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#   'nowVal': 18785,
#   'risefall': '2',
#   'changeVal': 345,
#   'changeRate': 1.87,
#   'nav': None,
#   'threeMonthEarnRate': -0.0533,
#   'quant': 53099,
#   'amonut': 992,
#   'marketSum': 2480},
#  {'itemcode': '143850',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500선물(H)',
#   'nowVal': 52045,
#   'risefall': '2',
#   'changeVal': 760,
#   'changeRate': 1.48,
#   'nav': None,
#   'threeMonthEarnRate': 2.059,
#   'quant': 26476,
#   'amonut': 1376,
#   'marketSum': 2459},
#  {'itemcode': '108450',
#   'etfTabCode': 2,
#   'itemname': 'KINDEX 삼성그룹섹터가중',
#   'nowVal': 16435,
#   'risefall': '2',
#   'changeVal': 345,
#   'changeRate': 2.14,
#   'nav': 16435.0,
#   'threeMonthEarnRate': -5.1645,
#   'quant': 1553,
#   'amonut': 25,
#   'marketSum': 2449},
#  {'itemcode': '168580',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 중국본토CSI300',
#   'nowVal': 32000,
#   'risefall': '2',
#   'changeVal': 250,
#   'changeRate': 0.79,
#   'nav': None,
#   'threeMonthEarnRate': 0.1564,
#   'quant': 324122,
#   'amonut': 10356,
#   'marketSum': 2400},
#  {'itemcode': '132030',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 골드선물(H)',
#   'nowVal': 12120,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.08,
#   'nav': None,
#   'threeMonthEarnRate': -2.5724,
#   'quant': 63537,
#   'amonut': 771,
#   'marketSum': 2291},
#  {'itemcode': '245710',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 베트남VN30(합성)',
#   'nowVal': 23155,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.17,
#   'nav': None,
#   'threeMonthEarnRate': 10.4986,
#   'quant': 96910,
#   'amonut': 2221,
#   'marketSum': 2269},
#  {'itemcode': '091160',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 반도체',
#   'nowVal': 32360,
#   'risefall': '2',
#   'changeVal': 840,
#   'changeRate': 2.66,
#   'nav': 32391.0,
#   'threeMonthEarnRate': -15.7731,
#   'quant': 230046,
#   'amonut': 7421,
#   'marketSum': 2233},
#  {'itemcode': '161510',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG 고배당주',
#   'nowVal': 12850,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 1.02,
#   'nav': 12884.0,
#   'threeMonthEarnRate': 2.8411,
#   'quant': 107139,
#   'amonut': 1374,
#   'marketSum': 2159},
#  {'itemcode': '332930',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200TR',
#   'nowVal': 46985,
#   'risefall': '2',
#   'changeVal': 500,
#   'changeRate': 1.08,
#   'nav': 46984.0,
#   'threeMonthEarnRate': -9.566,
#   'quant': 724,
#   'amonut': 34,
#   'marketSum': 2020},
#  {'itemcode': '190620',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 단기통안채',
#   'nowVal': 100520,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 100514.0,
#   'threeMonthEarnRate': 0.1644,
#   'quant': 721,
#   'amonut': 72,
#   'marketSum': 1975},
#  {'itemcode': '261220',
#   'etfTabCode': 5,
#   'itemname': 'KODEX WTI원유선물(H)',
#   'nowVal': 12540,
#   'risefall': '2',
#   'changeVal': 165,
#   'changeRate': 1.33,
#   'nav': None,
#   'threeMonthEarnRate': 15.6293,
#   'quant': 322956,
#   'amonut': 4033,
#   'marketSum': 1953},
#  {'itemcode': '326240',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR IT플러스',
#   'nowVal': 20780,
#   'risefall': '2',
#   'changeVal': 300,
#   'changeRate': 1.46,
#   'nav': 20777.0,
#   'threeMonthEarnRate': -10.7197,
#   'quant': 211552,
#   'amonut': 4391,
#   'marketSum': 1920},
#  {'itemcode': '272580',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 단기채권액티브',
#   'nowVal': 50200,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.01,
#   'nav': 50195.0,
#   'threeMonthEarnRate': 0.2196,
#   'quant': 2978,
#   'amonut': 149,
#   'marketSum': 1920},
#  {'itemcode': '390950',
#   'etfTabCode': 6,
#   'itemname': 'HANARO 단기채권액티브',
#   'nowVal': 100200,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 100201.0,
#   'threeMonthEarnRate': 0.1249,
#   'quant': 13,
#   'amonut': 1,
#   'marketSum': 1747},
#  {'itemcode': '302450',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스피',
#   'nowVal': 30345,
#   'risefall': '2',
#   'changeVal': 345,
#   'changeRate': 1.15,
#   'nav': 30348.0,
#   'threeMonthEarnRate': -8.1707,
#   'quant': 1407,
#   'amonut': 42,
#   'marketSum': 1714},
#  {'itemcode': '182480',
#   'etfTabCode': 7,
#   'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#   'nowVal': 15255,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.63,
#   'nav': None,
#   'threeMonthEarnRate': 1.6525,
#   'quant': 26596,
#   'amonut': 406,
#   'marketSum': 1678},
#  {'itemcode': '278240',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150선물레버리지',
#   'nowVal': 15305,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.56,
#   'nav': 15311.0,
#   'threeMonthEarnRate': -6.4201,
#   'quant': 5242,
#   'amonut': 79,
#   'marketSum': 1602},
#  {'itemcode': '232080',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스닥150',
#   'nowVal': 14615,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 0.31,
#   'nav': 14737.0,
#   'threeMonthEarnRate': -3.4039,
#   'quant': 91531,
#   'amonut': 1335,
#   'marketSum': 1593},
#  {'itemcode': '372330',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 차이나항셍테크',
#   'nowVal': 8305,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.78,
#   'nav': None,
#   'threeMonthEarnRate': -15.4277,
#   'quant': 208413,
#   'amonut': 1727,
#   'marketSum': 1586},
#  {'itemcode': '270810',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150',
#   'nowVal': 14320,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.25,
#   'nav': 14453.0,
#   'threeMonthEarnRate': -3.0796,
#   'quant': 13004,
#   'amonut': 185,
#   'marketSum': 1578},
#  {'itemcode': '143860',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 헬스케어',
#   'nowVal': 38465,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.05,
#   'nav': 38597.0,
#   'threeMonthEarnRate': -13.4354,
#   'quant': 35602,
#   'amonut': 1368,
#   'marketSum': 1554},
#  {'itemcode': '148070',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 국고채10년',
#   'nowVal': 118145,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.03,
#   'nav': 118120.0,
#   'threeMonthEarnRate': -2.4482,
#   'quant': 2526,
#   'amonut': 298,
#   'marketSum': 1524},
#  {'itemcode': '379810',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국나스닥100TR',
#   'nowVal': 11730,
#   'risefall': '2',
#   'changeVal': 120,
#   'changeRate': 1.03,
#   'nav': None,
#   'threeMonthEarnRate': 4.6387,
#   'quant': 415196,
#   'amonut': 4871,
#   'marketSum': 1513},
#  {'itemcode': '150460',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 중국소비테마',
#   'nowVal': 8695,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.99,
#   'nav': 8702.0,
#   'threeMonthEarnRate': -5.643,
#   'quant': 17975,
#   'amonut': 155,
#   'marketSum': 1484},
#  {'itemcode': '385560',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KIS국고채30년Enhanced',
#   'nowVal': 99235,
#   'risefall': '5',
#   'changeVal': -655,
#   'changeRate': -0.66,
#   'nav': 99031.0,
#   'threeMonthEarnRate': -5.0265,
#   'quant': 117,
#   'amonut': 11,
#   'marketSum': 1469},
#  {'itemcode': '379800',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P500TR',
#   'nowVal': 11590,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 1.09,
#   'nav': None,
#   'threeMonthEarnRate': 5.6036,
#   'quant': 196195,
#   'amonut': 2271,
#   'marketSum': 1460},
#  {'itemcode': '325020',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 배당가치',
#   'nowVal': 13175,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 1.0,
#   'nav': 13165.0,
#   'threeMonthEarnRate': -4.321,
#   'quant': 3042,
#   'amonut': 40,
#   'marketSum': 1410},
#  {'itemcode': '394660',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#   'nowVal': 10895,
#   'risefall': '2',
#   'changeVal': 110,
#   'changeRate': 1.02,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 221069,
#   'amonut': 2403,
#   'marketSum': 1386},
#  {'itemcode': '368590',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국나스닥100',
#   'nowVal': 13290,
#   'risefall': '2',
#   'changeVal': 160,
#   'changeRate': 1.22,
#   'nav': None,
#   'threeMonthEarnRate': 4.6456,
#   'quant': 67425,
#   'amonut': 896,
#   'marketSum': 1369},
#  {'itemcode': '138540',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 현대차그룹+펀더멘털',
#   'nowVal': 25505,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.1,
#   'nav': 25504.0,
#   'threeMonthEarnRate': -8.1398,
#   'quant': 24549,
#   'amonut': 626,
#   'marketSum': 1357},
#  {'itemcode': '136340',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 중기우량회사채',
#   'nowVal': 104395,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.04,
#   'nav': 104438.0,
#   'threeMonthEarnRate': -0.472,
#   'quant': 624,
#   'amonut': 65,
#   'marketSum': 1347},
#  {'itemcode': '267770',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 200선물레버리지',
#   'nowVal': 17720,
#   'risefall': '2',
#   'changeVal': 375,
#   'changeRate': 2.16,
#   'nav': 17786.0,
#   'threeMonthEarnRate': -18.9943,
#   'quant': 352693,
#   'amonut': 6243,
#   'marketSum': 1329},
#  {'itemcode': '219480',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P500선물(H)',
#   'nowVal': 21440,
#   'risefall': '2',
#   'changeVal': 310,
#   'changeRate': 1.47,
#   'nav': None,
#   'threeMonthEarnRate': 2.0952,
#   'quant': 42907,
#   'amonut': 919,
#   'marketSum': 1319},
#  {'itemcode': '329750',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국달러단기채권액티브',
#   'nowVal': 10115,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.39,
#   'nav': None,
#   'threeMonthEarnRate': 3.4782,
#   'quant': 162079,
#   'amonut': 1640,
#   'marketSum': 1315},
#  {'itemcode': '252710',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 200선물인버스2X',
#   'nowVal': 2340,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -2.09,
#   'nav': 2328.0,
#   'threeMonthEarnRate': 20.9302,
#   'quant': 6745079,
#   'amonut': 15783,
#   'marketSum': 1280},
#  {'itemcode': '091230',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 반도체',
#   'nowVal': 33245,
#   'risefall': '2',
#   'changeVal': 795,
#   'changeRate': 2.45,
#   'nav': 33235.0,
#   'threeMonthEarnRate': -15.5897,
#   'quant': 53347,
#   'amonut': 1769,
#   'marketSum': 1263},
#  {'itemcode': '228800',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 여행레저',
#   'nowVal': 5760,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.7,
#   'nav': 5769.0,
#   'threeMonthEarnRate': 7.2625,
#   'quant': 821256,
#   'amonut': 4734,
#   'marketSum': 1246},
#  {'itemcode': '395750',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG ESG가치주액티브',
#   'nowVal': 9405,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.53,
#   'nav': 9433.0,
#   'threeMonthEarnRate': None,
#   'quant': 8590,
#   'amonut': 80,
#   'marketSum': 1213},
#  {'itemcode': '322400',
#   'etfTabCode': 2,
#   'itemname': 'HANARO e커머스',
#   'nowVal': 18510,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 0.71,
#   'nav': 18506.0,
#   'threeMonthEarnRate': -11.4778,
#   'quant': 39177,
#   'amonut': 724,
#   'marketSum': 1203},
#  {'itemcode': '204480',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#   'nowVal': 32140,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.09,
#   'nav': None,
#   'threeMonthEarnRate': -2.3991,
#   'quant': 29228,
#   'amonut': 935,
#   'marketSum': 1189},
#  {'itemcode': '273140',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기변동금리부채권액티브',
#   'nowVal': 102845,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.02,
#   'nav': 102841.0,
#   'threeMonthEarnRate': 0.2339,
#   'quant': 3,
#   'amonut': 0,
#   'marketSum': 1143},
#  {'itemcode': '283580',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 차이나CSI300',
#   'nowVal': 14590,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.07,
#   'nav': None,
#   'threeMonthEarnRate': 0.0685,
#   'quant': 20351,
#   'amonut': 296,
#   'marketSum': 1138},
#  {'itemcode': '367760',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR Fn5G테크',
#   'nowVal': 9860,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.97,
#   'nav': 9861.0,
#   'threeMonthEarnRate': -14.5581,
#   'quant': 53884,
#   'amonut': 530,
#   'marketSum': 1129},
#  {'itemcode': '309230',
#   'etfTabCode': 2,
#   'itemname': 'KINDEX 미국WideMoat가치주',
#   'nowVal': 18075,
#   'risefall': '2',
#   'changeVal': 195,
#   'changeRate': 1.09,
#   'nav': None,
#   'threeMonthEarnRate': 5.4858,
#   'quant': 85581,
#   'amonut': 1543,
#   'marketSum': 1121},
#  {'itemcode': '298770',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 한국대만IT프리미어',
#   'nowVal': 19045,
#   'risefall': '2',
#   'changeVal': 280,
#   'changeRate': 1.49,
#   'nav': None,
#   'threeMonthEarnRate': -8.3053,
#   'quant': 10580,
#   'amonut': 201,
#   'marketSum': 1105},
#  {'itemcode': '261240',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물',
#   'nowVal': 10450,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.38,
#   'nav': 10465.0,
#   'threeMonthEarnRate': 3.3119,
#   'quant': 444289,
#   'amonut': 4646,
#   'marketSum': 1090},
#  {'itemcode': '139220',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 건설',
#   'nowVal': 3260,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.77,
#   'nav': 3269.0,
#   'threeMonthEarnRate': -5.0947,
#   'quant': 512845,
#   'amonut': 1668,
#   'marketSum': 1071},
#  {'itemcode': '328370',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 코스피TR',
#   'nowVal': 15220,
#   'risefall': '2',
#   'changeVal': 135,
#   'changeRate': 0.89,
#   'nav': 15221.0,
#   'threeMonthEarnRate': -7.4491,
#   'quant': 17232,
#   'amonut': 261,
#   'marketSum': 1065},
#  {'itemcode': '325010',
#   'etfTabCode': 2,
#   'itemname': 'KODEX Fn성장',
#   'nowVal': 17345,
#   'risefall': '2',
#   'changeVal': 160,
#   'changeRate': 0.93,
#   'nav': 17334.0,
#   'threeMonthEarnRate': -9.638,
#   'quant': 29926,
#   'amonut': 518,
#   'marketSum': 1041},
#  {'itemcode': '114260',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국고채3년',
#   'nowVal': 57455,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.03,
#   'nav': 57497.0,
#   'threeMonthEarnRate': -0.5797,
#   'quant': 824,
#   'amonut': 47,
#   'marketSum': 1034},
#  {'itemcode': '144600',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 은선물(H)',
#   'nowVal': 4825,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 1.47,
#   'nav': None,
#   'threeMonthEarnRate': -11.3052,
#   'quant': 388631,
#   'amonut': 1874,
#   'marketSum': 1028},
#  {'itemcode': '329200',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 부동산인프라고배당',
#   'nowVal': 5915,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.25,
#   'nav': 5936.0,
#   'threeMonthEarnRate': 1.6323,
#   'quant': 122121,
#   'amonut': 721,
#   'marketSum': 1014},
#  {'itemcode': '157490',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 소프트웨어',
#   'nowVal': 16580,
#   'risefall': '2',
#   'changeVal': 150,
#   'changeRate': 0.91,
#   'nav': 16610.0,
#   'threeMonthEarnRate': -16.178,
#   'quant': 106829,
#   'amonut': 1768,
#   'marketSum': 975},
#  {'itemcode': '329650',
#   'etfTabCode': 7,
#   'itemname': 'KODEX TRF3070',
#   'nowVal': 11370,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.49,
#   'nav': 11317.0,
#   'threeMonthEarnRate': 0.5305,
#   'quant': 61479,
#   'amonut': 698,
#   'marketSum': 966},
#  {'itemcode': '139280',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 경기방어',
#   'nowVal': 11425,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 0.62,
#   'nav': 11424.0,
#   'threeMonthEarnRate': -9.6838,
#   'quant': 10565,
#   'amonut': 120,
#   'marketSum': 935},
#  {'itemcode': '225040',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#   'nowVal': 33565,
#   'risefall': '2',
#   'changeVal': 1005,
#   'changeRate': 3.09,
#   'nav': None,
#   'threeMonthEarnRate': 2.8181,
#   'quant': 26169,
#   'amonut': 875,
#   'marketSum': 906},
#  {'itemcode': '122260',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 통안채1년',
#   'nowVal': 101280,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 101284.0,
#   'threeMonthEarnRate': 0.1087,
#   'quant': 38199,
#   'amonut': 3868,
#   'marketSum': 901},
#  {'itemcode': '117700',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 건설',
#   'nowVal': 3710,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 1.64,
#   'nav': 3713.0,
#   'threeMonthEarnRate': -6.076,
#   'quant': 192882,
#   'amonut': 711,
#   'marketSum': 894},
#  {'itemcode': '364970',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX바이오K-뉴딜',
#   'nowVal': 8910,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.28,
#   'nav': 8908.0,
#   'threeMonthEarnRate': -16.2201,
#   'quant': 302812,
#   'amonut': 2689,
#   'marketSum': 887},
#  {'itemcode': '371470',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#   'nowVal': 11325,
#   'risefall': '5',
#   'changeVal': -90,
#   'changeRate': -0.79,
#   'nav': None,
#   'threeMonthEarnRate': -14.0092,
#   'quant': 48134,
#   'amonut': 545,
#   'marketSum': 879},
#  {'itemcode': '174360',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 중국본토대형주CSI100',
#   'nowVal': 21780,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.25,
#   'nav': None,
#   'threeMonthEarnRate': 0.0,
#   'quant': 6384,
#   'amonut': 138,
#   'marketSum': 849},
#  {'itemcode': '306520',
#   'etfTabCode': 3,
#   'itemname': 'HANARO 200선물인버스',
#   'nowVal': 9375,
#   'risefall': '5',
#   'changeVal': -95,
#   'changeRate': -1.0,
#   'nav': 9358.0,
#   'threeMonthEarnRate': 10.0352,
#   'quant': 11493,
#   'amonut': 107,
#   'marketSum': 839},
#  {'itemcode': '304940',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국나스닥100선물(H)',
#   'nowVal': 19140,
#   'risefall': '2',
#   'changeVal': 270,
#   'changeRate': 1.43,
#   'nav': None,
#   'threeMonthEarnRate': 1.0292,
#   'quant': 64298,
#   'amonut': 1231,
#   'marketSum': 833},
#  {'itemcode': '387270',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌BBIG액티브',
#   'nowVal': 11815,
#   'risefall': '2',
#   'changeVal': 165,
#   'changeRate': 1.42,
#   'nav': None,
#   'threeMonthEarnRate': 3.5949,
#   'quant': 91885,
#   'amonut': 1080,
#   'marketSum': 821},
#  {'itemcode': '195930',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 유로스탁스50(합성 H)',
#   'nowVal': 14170,
#   'risefall': '2',
#   'changeVal': 190,
#   'changeRate': 1.36,
#   'nav': None,
#   'threeMonthEarnRate': 2.0525,
#   'quant': 42459,
#   'amonut': 601,
#   'marketSum': 808},
#  {'itemcode': '266160',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 고배당',
#   'nowVal': 12550,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 1.01,
#   'nav': 12549.0,
#   'threeMonthEarnRate': -2.4486,
#   'quant': 17807,
#   'amonut': 223,
#   'marketSum': 778},
#  {'itemcode': '195980',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#   'nowVal': 12290,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 1.07,
#   'nav': None,
#   'threeMonthEarnRate': -5.0232,
#   'quant': 24291,
#   'amonut': 297,
#   'marketSum': 764},
#  {'itemcode': '376410',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 탄소효율그린뉴딜',
#   'nowVal': 9620,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 0.84,
#   'nav': 9622.0,
#   'threeMonthEarnRate': -8.381,
#   'quant': 17706,
#   'amonut': 169,
#   'marketSum': 731},
#  {'itemcode': '387280',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 퓨처모빌리티액티브',
#   'nowVal': 11530,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.56,
#   'nav': 11579.0,
#   'threeMonthEarnRate': 2.4888,
#   'quant': 37309,
#   'amonut': 431,
#   'marketSum': 721},
#  {'itemcode': '385520',
#   'etfTabCode': 2,
#   'itemname': 'KODEX K-미래차액티브',
#   'nowVal': 10975,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.27,
#   'nav': 10975.0,
#   'threeMonthEarnRate': -0.8134,
#   'quant': 70081,
#   'amonut': 767,
#   'marketSum': 702},
#  {'itemcode': '245340',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국다우존스30',
#   'nowVal': 21010,
#   'risefall': '2',
#   'changeVal': 250,
#   'changeRate': 1.2,
#   'nav': None,
#   'threeMonthEarnRate': 4.3975,
#   'quant': 12517,
#   'amonut': 262,
#   'marketSum': 693},
#  {'itemcode': '256750',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 차이나심천ChiNext(합성)',
#   'nowVal': 14735,
#   'risefall': '2',
#   'changeVal': 235,
#   'changeRate': 1.62,
#   'nav': None,
#   'threeMonthEarnRate': -3.0274,
#   'quant': 17781,
#   'amonut': 258,
#   'marketSum': 693},
#  {'itemcode': '114820',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 국채3년',
#   'nowVal': 109335,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.01,
#   'nav': 109419.0,
#   'threeMonthEarnRate': -0.5513,
#   'quant': 1454,
#   'amonut': 158,
#   'marketSum': 689},
#  {'itemcode': '123310',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 인버스',
#   'nowVal': 4510,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.99,
#   'nav': 4503.0,
#   'threeMonthEarnRate': 10.2689,
#   'quant': 370953,
#   'amonut': 1673,
#   'marketSum': 686},
#  {'itemcode': '305080',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국채10년선물',
#   'nowVal': 12065,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.21,
#   'nav': None,
#   'threeMonthEarnRate': 2.4628,
#   'quant': 22099,
#   'amonut': 266,
#   'marketSum': 676},
#  {'itemcode': '130730',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 단기자금',
#   'nowVal': 101270,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 101271.0,
#   'threeMonthEarnRate': 0.1532,
#   'quant': 83218,
#   'amonut': 8427,
#   'marketSum': 666},
#  {'itemcode': '130680',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 원유선물Enhanced(H)',
#   'nowVal': 3780,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 1.2,
#   'nav': None,
#   'threeMonthEarnRate': 15.4198,
#   'quant': 309977,
#   'amonut': 1167,
#   'marketSum': 663},
#  {'itemcode': '277630',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스피',
#   'nowVal': 30645,
#   'risefall': '2',
#   'changeVal': 305,
#   'changeRate': 1.01,
#   'nav': 30698.0,
#   'threeMonthEarnRate': -7.8069,
#   'quant': 92132,
#   'amonut': 2820,
#   'marketSum': 659},
#  {'itemcode': '233160',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스닥150 레버리지',
#   'nowVal': 15865,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.41,
#   'nav': 16007.0,
#   'threeMonthEarnRate': -7.2494,
#   'quant': 148086,
#   'amonut': 2338,
#   'marketSum': 643},
#  {'itemcode': '385510',
#   'etfTabCode': 2,
#   'itemname': 'KODEX K-신재생에너지액티브',
#   'nowVal': 12475,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.08,
#   'nav': 12472.0,
#   'threeMonthEarnRate': 15.2957,
#   'quant': 119248,
#   'amonut': 1485,
#   'marketSum': 642},
#  {'itemcode': '245360',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나HSCEI',
#   'nowVal': 11240,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.09,
#   'nav': None,
#   'threeMonthEarnRate': -8.7292,
#   'quant': 30186,
#   'amonut': 338,
#   'marketSum': 641},
#  {'itemcode': '228810',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 미디어컨텐츠',
#   'nowVal': 9240,
#   'risefall': '2',
#   'changeVal': 155,
#   'changeRate': 1.71,
#   'nav': 9243.0,
#   'threeMonthEarnRate': 7.8179,
#   'quant': 1035820,
#   'amonut': 9517,
#   'marketSum': 638},
#  {'itemcode': '363510',
#   'etfTabCode': 6,
#   'itemname': 'SOL KIS단기통안채',
#   'nowVal': 100445,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 100465.0,
#   'threeMonthEarnRate': 0.1046,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 632},
#  {'itemcode': '365000',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX인터넷K-뉴딜',
#   'nowVal': 11675,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.04,
#   'nav': 11728.0,
#   'threeMonthEarnRate': -12.1851,
#   'quant': 143981,
#   'amonut': 1685,
#   'marketSum': 630},
#  {'itemcode': '368190',
#   'etfTabCode': 2,
#   'itemname': 'HANARO Fn K-뉴딜디지털플러스',
#   'nowVal': 12235,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.33,
#   'nav': 12239.0,
#   'threeMonthEarnRate': -11.2442,
#   'quant': 8147,
#   'amonut': 99,
#   'marketSum': 630},
#  {'itemcode': '395760',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG ESG성장주액티브',
#   'nowVal': 9440,
#   'risefall': '2',
#   'changeVal': 105,
#   'changeRate': 1.12,
#   'nav': 9465.0,
#   'threeMonthEarnRate': None,
#   'quant': 118,
#   'amonut': 1,
#   'marketSum': 628},
#  {'itemcode': '396510',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나클린에너지SOLACTIVE',
#   'nowVal': 10590,
#   'risefall': '2',
#   'changeVal': 135,
#   'changeRate': 1.29,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 90892,
#   'amonut': 957,
#   'marketSum': 618},
#  {'itemcode': '397410',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 국채선물5년추종인버스',
#   'nowVal': 51015,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.03,
#   'nav': 51008.0,
#   'threeMonthEarnRate': None,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 615},
#  {'itemcode': '302190',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 중장기국채',
#   'nowVal': 51530,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.02,
#   'nav': 51554.0,
#   'threeMonthEarnRate': -1.4252,
#   'quant': 46,
#   'amonut': 2,
#   'marketSum': 587},
#  {'itemcode': '102970',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 증권',
#   'nowVal': 7930,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 0.89,
#   'nav': 7944.0,
#   'threeMonthEarnRate': -5.987,
#   'quant': 110223,
#   'amonut': 871,
#   'marketSum': 575},
#  {'itemcode': '315960',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 대형고배당10TR',
#   'nowVal': 15490,
#   'risefall': '2',
#   'changeVal': 235,
#   'changeRate': 1.54,
#   'nav': 15491.0,
#   'threeMonthEarnRate': -9.0162,
#   'quant': 6910,
#   'amonut': 106,
#   'marketSum': 550},
#  {'itemcode': '219390',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국S&P원유생산기업(합성 H)',
#   'nowVal': 4745,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 1.61,
#   'nav': None,
#   'threeMonthEarnRate': 20.4314,
#   'quant': 350949,
#   'amonut': 1658,
#   'marketSum': 546},
#  {'itemcode': '354350',
#   'etfTabCode': 4,
#   'itemname': 'HANARO 글로벌럭셔리S&P(합성)',
#   'nowVal': 18240,
#   'risefall': '2',
#   'changeVal': 200,
#   'changeRate': 1.11,
#   'nav': None,
#   'threeMonthEarnRate': 0.2748,
#   'quant': 37682,
#   'amonut': 686,
#   'marketSum': 538},
#  {'itemcode': '200250',
#   'etfTabCode': 4,
#   'itemname': 'KOSEF 인도Nifty50(합성)',
#   'nowVal': 19785,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.28,
#   'nav': None,
#   'threeMonthEarnRate': 19.4746,
#   'quant': 56777,
#   'amonut': 1125,
#   'marketSum': 534},
#  {'itemcode': '282000',
#   'etfTabCode': 3,
#   'itemname': 'KBSTAR 국고채3년선물인버스',
#   'nowVal': 100880,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.04,
#   'nav': 100864.0,
#   'threeMonthEarnRate': 0.7188,
#   'quant': 9,
#   'amonut': 0,
#   'marketSum': 534},
#  {'itemcode': '371450',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌클라우드컴퓨팅INDXX',
#   'nowVal': 12895,
#   'risefall': '2',
#   'changeVal': 150,
#   'changeRate': 1.18,
#   'nav': None,
#   'threeMonthEarnRate': 12.7185,
#   'quant': 36295,
#   'amonut': 467,
#   'marketSum': 531},
#  {'itemcode': '117680',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 철강',
#   'nowVal': 9725,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.57,
#   'nav': 9743.0,
#   'threeMonthEarnRate': -5.4908,
#   'quant': 186015,
#   'amonut': 1807,
#   'marketSum': 531},
#  {'itemcode': '363580',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 200IT TR',
#   'nowVal': 12885,
#   'risefall': '2',
#   'changeVal': 355,
#   'changeRate': 2.83,
#   'nav': 12882.0,
#   'threeMonthEarnRate': -12.7033,
#   'quant': 2318,
#   'amonut': 29,
#   'marketSum': 528},
#  {'itemcode': '289260',
#   'etfTabCode': 2,
#   'itemname': 'TIGER MSCI KOREA ESG리더스',
#   'nowVal': 11335,
#   'risefall': '2',
#   'changeVal': 195,
#   'changeRate': 1.75,
#   'nav': 11341.0,
#   'threeMonthEarnRate': -8.9559,
#   'quant': 491,
#   'amonut': 5,
#   'marketSum': 527},
#  {'itemcode': '266360',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 미디어&엔터테인먼트',
#   'nowVal': 23805,
#   'risefall': '2',
#   'changeVal': 225,
#   'changeRate': 0.95,
#   'nav': 23869.0,
#   'threeMonthEarnRate': -11.6042,
#   'quant': 27005,
#   'amonut': 642,
#   'marketSum': 524},
#  {'itemcode': '337160',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 200ESG',
#   'nowVal': 14060,
#   'risefall': '2',
#   'changeVal': 185,
#   'changeRate': 1.33,
#   'nav': 14056.0,
#   'threeMonthEarnRate': -9.9296,
#   'quant': 2695,
#   'amonut': 37,
#   'marketSum': 520},
#  {'itemcode': '139230',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 중공업',
#   'nowVal': 3395,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 2.41,
#   'nav': 3386.0,
#   'threeMonthEarnRate': -12.3871,
#   'quant': 341480,
#   'amonut': 1152,
#   'marketSum': 504},
#  {'itemcode': '336160',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 금융채액티브',
#   'nowVal': 102305,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 102348.0,
#   'threeMonthEarnRate': -0.4283,
#   'quant': 94,
#   'amonut': 9,
#   'marketSum': 501},
#  {'itemcode': '099140',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 차이나H',
#   'nowVal': 19085,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.13,
#   'nav': None,
#   'threeMonthEarnRate': -9.1624,
#   'quant': 19761,
#   'amonut': 376,
#   'marketSum': 496},
#  {'itemcode': '256440',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 인도네시아MSCI(합성)',
#   'nowVal': 9725,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.67,
#   'nav': None,
#   'threeMonthEarnRate': 25.2414,
#   'quant': 127869,
#   'amonut': 1243,
#   'marketSum': 496},
#  {'itemcode': '379780',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국S&P500',
#   'nowVal': 11505,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 1.14,
#   'nav': None,
#   'threeMonthEarnRate': 5.4054,
#   'quant': 27504,
#   'amonut': 316,
#   'marketSum': 495},
#  {'itemcode': '304780',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200선물레버리지',
#   'nowVal': 25710,
#   'risefall': '2',
#   'changeVal': 570,
#   'changeRate': 2.27,
#   'nav': 25807.0,
#   'threeMonthEarnRate': -19.0237,
#   'quant': 6708,
#   'amonut': 172,
#   'marketSum': 488},
#  {'itemcode': '388280',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR Fn컨택트대표',
#   'nowVal': 10120,
#   'risefall': '2',
#   'changeVal': 120,
#   'changeRate': 1.2,
#   'nav': 10148.0,
#   'threeMonthEarnRate': 2.1706,
#   'quant': 151278,
#   'amonut': 1527,
#   'marketSum': 470},
#  {'itemcode': '266370',
#   'etfTabCode': 2,
#   'itemname': 'KODEX IT',
#   'nowVal': 19295,
#   'risefall': '2',
#   'changeVal': 465,
#   'changeRate': 2.47,
#   'nav': 19297.0,
#   'threeMonthEarnRate': -10.5264,
#   'quant': 15148,
#   'amonut': 291,
#   'marketSum': 463},
#  {'itemcode': '375770',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 탄소효율그린뉴딜',
#   'nowVal': 9610,
#   'risefall': '2',
#   'changeVal': 120,
#   'changeRate': 1.26,
#   'nav': 9610.0,
#   'threeMonthEarnRate': -8.3016,
#   'quant': 7697,
#   'amonut': 73,
#   'marketSum': 461},
#  {'itemcode': '292190',
#   'etfTabCode': 1,
#   'itemname': 'KODEX KRX300',
#   'nowVal': 18270,
#   'risefall': '2',
#   'changeVal': 210,
#   'changeRate': 1.16,
#   'nav': 18271.0,
#   'threeMonthEarnRate': -8.9687,
#   'quant': 5914,
#   'amonut': 107,
#   'marketSum': 457},
#  {'itemcode': '114460',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 국고채3년',
#   'nowVal': 105505,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 0.08,
#   'nav': 105525.0,
#   'threeMonthEarnRate': -0.4867,
#   'quant': 16,
#   'amonut': 1,
#   'marketSum': 443},
#  {'itemcode': '228790',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 화장품',
#   'nowVal': 3275,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 2.02,
#   'nav': 3272.0,
#   'threeMonthEarnRate': -16.7726,
#   'quant': 713149,
#   'amonut': 2312,
#   'marketSum': 443},
#  {'itemcode': '356540',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX KIS종합채권(AA-이상)액티브',
#   'nowVal': 97385,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.09,
#   'nav': 97397.0,
#   'threeMonthEarnRate': -1.2022,
#   'quant': 5,
#   'amonut': 0,
#   'marketSum': 442},
#  {'itemcode': '361580',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 200TR',
#   'nowVal': 20250,
#   'risefall': '2',
#   'changeVal': 235,
#   'changeRate': 1.17,
#   'nav': 20238.0,
#   'threeMonthEarnRate': -9.5175,
#   'quant': 1607,
#   'amonut': 32,
#   'marketSum': 435},
#  {'itemcode': '204450',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 차이나H레버리지(H)',
#   'nowVal': 4735,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.64,
#   'nav': None,
#   'threeMonthEarnRate': -24.8413,
#   'quant': 60813,
#   'amonut': 286,
#   'marketSum': 421},
#  {'itemcode': '203780',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국나스닥바이오',
#   'nowVal': 21650,
#   'risefall': '2',
#   'changeVal': 210,
#   'changeRate': 0.98,
#   'nav': None,
#   'threeMonthEarnRate': 3.3906,
#   'quant': 8076,
#   'amonut': 174,
#   'marketSum': 411},
#  {'itemcode': '337140',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 코스피대형주',
#   'nowVal': 13885,
#   'risefall': '2',
#   'changeVal': 140,
#   'changeRate': 1.02,
#   'nav': 13908.0,
#   'threeMonthEarnRate': -9.867,
#   'quant': 5609,
#   'amonut': 77,
#   'marketSum': 403},
#  {'itemcode': '385720',
#   'etfTabCode': 1,
#   'itemname': 'TIMEFOLIO Kstock액티브',
#   'nowVal': 10120,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 0.7,
#   'nav': 10183.0,
#   'threeMonthEarnRate': -2.6924,
#   'quant': 11425,
#   'amonut': 115,
#   'marketSum': 395},
#  {'itemcode': '326230',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 내수주플러스',
#   'nowVal': 10395,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 1.22,
#   'nav': 10391.0,
#   'threeMonthEarnRate': -8.4141,
#   'quant': 7,
#   'amonut': 0,
#   'marketSum': 391},
#  {'itemcode': '243880',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200IT레버리지',
#   'nowVal': 51660,
#   'risefall': '2',
#   'changeVal': 2340,
#   'changeRate': 4.74,
#   'nav': 52166.0,
#   'threeMonthEarnRate': -25.7919,
#   'quant': 17632,
#   'amonut': 907,
#   'marketSum': 387},
#  {'itemcode': '341850',
#   'etfTabCode': 7,
#   'itemname': 'TIGER KIS부동산인프라채권TR',
#   'nowVal': 5695,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.18,
#   'nav': 5712.0,
#   'threeMonthEarnRate': -0.0878,
#   'quant': 7193,
#   'amonut': 40,
#   'marketSum': 387},
#  {'itemcode': '269540',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG 미국S&P500(H)',
#   'nowVal': 18415,
#   'risefall': '2',
#   'changeVal': 235,
#   'changeRate': 1.29,
#   'nav': None,
#   'threeMonthEarnRate': 2.8196,
#   'quant': 11905,
#   'amonut': 219,
#   'marketSum': 387},
#  {'itemcode': '139270',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 금융',
#   'nowVal': 7105,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 1.36,
#   'nav': 7118.0,
#   'threeMonthEarnRate': 1.0668,
#   'quant': 90241,
#   'amonut': 640,
#   'marketSum': 387},
#  {'itemcode': '280930',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국러셀2000(H)',
#   'nowVal': 14860,
#   'risefall': '2',
#   'changeVal': 165,
#   'changeRate': 1.12,
#   'nav': None,
#   'threeMonthEarnRate': 3.9524,
#   'quant': 5078,
#   'amonut': 75,
#   'marketSum': 372},
#  {'itemcode': '276970',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P고배당커버드콜(합성 H)',
#   'nowVal': 10255,
#   'risefall': '2',
#   'changeVal': 105,
#   'changeRate': 1.03,
#   'nav': None,
#   'threeMonthEarnRate': 1.7764,
#   'quant': 15799,
#   'amonut': 161,
#   'marketSum': 369},
#  {'itemcode': '396500',
#   'etfTabCode': 2,
#   'itemname': 'TIGER Fn반도체TOP10',
#   'nowVal': 8385,
#   'risefall': '2',
#   'changeVal': 195,
#   'changeRate': 2.38,
#   'nav': 8385.0,
#   'threeMonthEarnRate': None,
#   'quant': 112716,
#   'amonut': 942,
#   'marketSum': 369},
#  {'itemcode': '400570',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 유럽탄소배출권선물ICE(H)',
#   'nowVal': 9940,
#   'risefall': '2',
#   'changeVal': 320,
#   'changeRate': 3.33,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 374541,
#   'amonut': 3715,
#   'marketSum': 369},
#  {'itemcode': '304770',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 코스닥150',
#   'nowVal': 14390,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.66,
#   'nav': 14522.0,
#   'threeMonthEarnRate': -3.0324,
#   'quant': 1321,
#   'amonut': 18,
#   'marketSum': 366},
#  {'itemcode': '169950',
# ...
#   'quant': 25,
#   'amonut': 0,
#   'marketSum': 62},
#  {'itemcode': '342500',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KRX국채선물3년10년스티프너',
#   'nowVal': 51330,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.08,
#   'nav': 51328.0,
#   'threeMonthEarnRate': 0.4599,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 62},
#  {'itemcode': '269530',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG S&P글로벌인프라',
#   'nowVal': 12185,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 1.08,
#   'nav': None,
#   'threeMonthEarnRate': 5.5435,
#   'quant': 13891,
#   'amonut': 167,
#   'marketSum': 61},
#  {'itemcode': '174350',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 로우볼',
#   'nowVal': 12630,
#   'risefall': '2',
#   'changeVal': 150,
#   'changeRate': 1.2,
#   'nav': 12629.0,
#   'threeMonthEarnRate': 0.7578,
#   'quant': 168,
#   'amonut': 2,
#   'marketSum': 61},
#  {'itemcode': '342610',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KRX국채선물3년10년플래트너',
#   'nowVal': 49800,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.05,
#   'nav': 49777.0,
#   'threeMonthEarnRate': -0.0803,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 60},
#  {'itemcode': '176710',
#   'etfTabCode': 6,
#   'itemname': '파워 중기국고채',
#   'nowVal': 98940,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 99006.0,
#   'threeMonthEarnRate': -0.4247,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 59},
#  {'itemcode': '290080',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200고배당커버드콜ATM',
#   'nowVal': 8460,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.77,
#   'nav': 8439.0,
#   'threeMonthEarnRate': 1.9277,
#   'quant': 20,
#   'amonut': 0,
#   'marketSum': 59},
#  {'itemcode': '261920',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 필리핀MSCI(합성)',
#   'nowVal': 14800,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.24,
#   'nav': None,
#   'threeMonthEarnRate': 12.2487,
#   'quant': 430,
#   'amonut': 6,
#   'marketSum': 59},
#  {'itemcode': '253280',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 헬스케어',
#   'nowVal': 14710,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.07,
#   'nav': 14709.0,
#   'threeMonthEarnRate': -11.3054,
#   'quant': 611,
#   'amonut': 8,
#   'marketSum': 59},
#  {'itemcode': '342620',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KRX국채선물3년10년플래트너2X',
#   'nowVal': 49040,
#   'risefall': '5',
#   'changeVal': -70,
#   'changeRate': -0.14,
#   'nav': 49019.0,
#   'threeMonthEarnRate': -0.2442,
#   'quant': 7,
#   'amonut': 0,
#   'marketSum': 59},
#  {'itemcode': '292340',
#   'etfTabCode': 2,
#   'itemname': '마이티 200커버드콜ATM레버리지',
#   'nowVal': 9775,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 9921.0,
#   'threeMonthEarnRate': -12.4337,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 59},
#  {'itemcode': '261270',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물인버스',
#   'nowVal': 9680,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.26,
#   'nav': 9686.0,
#   'threeMonthEarnRate': -3.4896,
#   'quant': 29650,
#   'amonut': 286,
#   'marketSum': 58},
#  {'itemcode': '315480',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200커뮤니케이션서비스',
#   'nowVal': 19360,
#   'risefall': '2',
#   'changeVal': 165,
#   'changeRate': 0.86,
#   'nav': 19326.0,
#   'threeMonthEarnRate': -13.9556,
#   'quant': 111,
#   'amonut': 2,
#   'marketSum': 58},
#  {'itemcode': '267440',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물(H)',
#   'nowVal': 11590,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.52,
#   'nav': None,
#   'threeMonthEarnRate': -1.0248,
#   'quant': 358,
#   'amonut': 4,
#   'marketSum': 58},
#  {'itemcode': '281990',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 중소형고배당',
#   'nowVal': 12740,
#   'risefall': '2',
#   'changeVal': 115,
#   'changeRate': 0.91,
#   'nav': 12738.0,
#   'threeMonthEarnRate': -0.0393,
#   'quant': 6517,
#   'amonut': 82,
#   'marketSum': 57},
#  {'itemcode': '346000',
#   'etfTabCode': 6,
#   'itemname': 'HANARO KAP초장기국고채',
#   'nowVal': 45050,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.07,
#   'nav': 45017.0,
#   'threeMonthEarnRate': -2.7124,
#   'quant': 215,
#   'amonut': 9,
#   'marketSum': 55},
#  {'itemcode': '321410',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 멀티에셋하이인컴(H)',
#   'nowVal': 10910,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.46,
#   'nav': None,
#   'threeMonthEarnRate': -0.0916,
#   'quant': 642,
#   'amonut': 7,
#   'marketSum': 55},
#  {'itemcode': '098560',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 방송통신',
#   'nowVal': 10065,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.55,
#   'nav': 10063.0,
#   'threeMonthEarnRate': -3.3606,
#   'quant': 1591,
#   'amonut': 15,
#   'marketSum': 54},
#  {'itemcode': '220130',
#   'etfTabCode': 4,
#   'itemname': 'SOL 중국본토 중소형 CSI500(합성 H)',
#   'nowVal': 6000,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.5,
#   'nav': None,
#   'threeMonthEarnRate': 3.1814,
#   'quant': 941,
#   'amonut': 5,
#   'marketSum': 54},
#  {'itemcode': '139310',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 금속선물(H)',
#   'nowVal': 7705,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 1.25,
#   'nav': None,
#   'threeMonthEarnRate': 11.7476,
#   'quant': 11256,
#   'amonut': 86,
#   'marketSum': 54},
#  {'itemcode': '295820',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 200동일가중',
#   'nowVal': 11795,
#   'risefall': '2',
#   'changeVal': 115,
#   'changeRate': 0.98,
#   'nav': 11782.0,
#   'threeMonthEarnRate': -4.1447,
#   'quant': 368,
#   'amonut': 4,
#   'marketSum': 53},
#  {'itemcode': '291890',
#   'etfTabCode': 4,
#   'itemname': 'KODEX MSCI EM선물(H)',
#   'nowVal': 10320,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.73,
#   'nav': None,
#   'threeMonthEarnRate': -4.4445,
#   'quant': 413,
#   'amonut': 4,
#   'marketSum': 52},
#  {'itemcode': '147970',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 모멘텀',
#   'nowVal': 25795,
#   'risefall': '2',
#   'changeVal': 265,
#   'changeRate': 1.04,
#   'nav': 25771.0,
#   'threeMonthEarnRate': -1.5459,
#   'quant': 100,
#   'amonut': 2,
#   'marketSum': 52},
#  {'itemcode': '292770',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국채선물3년인버스',
#   'nowVal': 50335,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 50288.0,
#   'threeMonthEarnRate': 0.7007,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 51},
#  {'itemcode': '299080',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 국채선물3년인버스',
#   'nowVal': 100700,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 100607.0,
#   'threeMonthEarnRate': 0.7861,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 50},
#  {'itemcode': '291680',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 차이나H선물인버스(H)',
#   'nowVal': 10925,
#   'risefall': '5',
#   'changeVal': -220,
#   'changeRate': -1.97,
#   'nav': None,
#   'threeMonthEarnRate': 11.3659,
#   'quant': 3625,
#   'amonut': 39,
#   'marketSum': 49},
#  {'itemcode': '334690',
#   'etfTabCode': 5,
#   'itemname': 'KBSTAR 팔라듐선물(H)',
#   'nowVal': 12285,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.16,
#   'nav': None,
#   'threeMonthEarnRate': -23.9555,
#   'quant': 7863,
#   'amonut': 96,
#   'marketSum': 49},
#  {'itemcode': '371870',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 차이나항셍테크',
#   'nowVal': 8180,
#   'risefall': '5',
#   'changeVal': -60,
#   'changeRate': -0.73,
#   'nav': None,
#   'threeMonthEarnRate': -15.321,
#   'quant': 5036,
#   'amonut': 40,
#   'marketSum': 49},
#  {'itemcode': '299070',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 국채선물10년인버스',
#   'nowVal': 97865,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 97766.0,
#   'threeMonthEarnRate': 3.1694,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 49},
#  {'itemcode': '285010',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200중공업',
#   'nowVal': 10505,
#   'risefall': '2',
#   'changeVal': 235,
#   'changeRate': 2.29,
#   'nav': 10501.0,
#   'threeMonthEarnRate': -12.0921,
#   'quant': 6417,
#   'amonut': 67,
#   'marketSum': 48},
#  {'itemcode': '275750',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150선물인버스',
#   'nowVal': 4595,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.22,
#   'nav': 4586.0,
#   'threeMonthEarnRate': 1.6592,
#   'quant': 18041,
#   'amonut': 82,
#   'marketSum': 48},
#  {'itemcode': '301410',
#   'etfTabCode': 3,
#   'itemname': 'ARIRANG 코스닥150선물인버스',
#   'nowVal': 6865,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.65,
#   'nav': 6882.0,
#   'threeMonthEarnRate': 1.3284,
#   'quant': 18930,
#   'amonut': 130,
#   'marketSum': 48},
#  {'itemcode': '333980',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG KS퀄리티가중TR',
#   'nowVal': 15460,
#   'risefall': '2',
#   'changeVal': 160,
#   'changeRate': 1.05,
#   'nav': 15457.0,
#   'threeMonthEarnRate': -6.3598,
#   'quant': 36,
#   'amonut': 0,
#   'marketSum': 46},
#  {'itemcode': '157500',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 증권',
#   'nowVal': 4660,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 1.53,
#   'nav': 4660.0,
#   'threeMonthEarnRate': -5.6681,
#   'quant': 13326,
#   'amonut': 61,
#   'marketSum': 46},
#  {'itemcode': '280920',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG 주도업종',
#   'nowVal': 11370,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.26,
#   'nav': 11366.0,
#   'threeMonthEarnRate': -10.4372,
#   'quant': 20,
#   'amonut': 0,
#   'marketSum': 45},
#  {'itemcode': '287300',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200건설',
#   'nowVal': 13245,
#   'risefall': '2',
#   'changeVal': 175,
#   'changeRate': 1.34,
#   'nav': 13255.0,
#   'threeMonthEarnRate': -4.7465,
#   'quant': 512,
#   'amonut': 6,
#   'marketSum': 45},
#  {'itemcode': '309210',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG KRX300헬스케어',
#   'nowVal': 11680,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 11754.0,
#   'threeMonthEarnRate': -13.8326,
#   'quant': 1372,
#   'amonut': 15,
#   'marketSum': 44},
#  {'itemcode': '227550',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 산업재',
#   'nowVal': 6655,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 1.14,
#   'nav': 6651.0,
#   'threeMonthEarnRate': -10.9104,
#   'quant': 10735,
#   'amonut': 71,
#   'marketSum': 44},
#  {'itemcode': '266550',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG 중형주저변동50',
#   'nowVal': 12440,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.48,
#   'nav': 12436.0,
#   'threeMonthEarnRate': 2.0927,
#   'quant': 395,
#   'amonut': 4,
#   'marketSum': 44},
#  {'itemcode': '280940',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 골드선물인버스(H)',
#   'nowVal': 7250,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.21,
#   'nav': None,
#   'threeMonthEarnRate': 1.6117,
#   'quant': 2104,
#   'amonut': 15,
#   'marketSum': 44},
#  {'itemcode': '253240',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 200선물인버스',
#   'nowVal': 5270,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -1.03,
#   'nav': 5257.0,
#   'threeMonthEarnRate': 9.7916,
#   'quant': 8459,
#   'amonut': 44,
#   'marketSum': 43},
#  {'itemcode': '291620',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 코스닥150선물인버스',
#   'nowVal': 7895,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.38,
#   'nav': 7897.0,
#   'threeMonthEarnRate': 1.4129,
#   'quant': 3908,
#   'amonut': 30,
#   'marketSum': 42},
#  {'itemcode': '227560',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 생활소비재',
#   'nowVal': 10855,
#   'risefall': '2',
#   'changeVal': 100,
#   'changeRate': 0.93,
#   'nav': 10878.0,
#   'threeMonthEarnRate': -10.1408,
#   'quant': 687,
#   'amonut': 7,
#   'marketSum': 41},
#  {'itemcode': '295020',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 국채선물10년인버스',
#   'nowVal': 48785,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.07,
#   'nav': 48766.0,
#   'threeMonthEarnRate': 2.6512,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 41},
#  {'itemcode': '302170',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 국채선물3년인버스',
#   'nowVal': 50400,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 50358.0,
#   'threeMonthEarnRate': 0.7199,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 40},
#  {'itemcode': '217790',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 가격조정',
#   'nowVal': 24960,
#   'risefall': '2',
#   'changeVal': 230,
#   'changeRate': 0.93,
#   'nav': 24921.0,
#   'threeMonthEarnRate': -6.8831,
#   'quant': 5,
#   'amonut': 0,
#   'marketSum': 40},
#  {'itemcode': '267450',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#   'nowVal': 7970,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.37,
#   'nav': None,
#   'threeMonthEarnRate': 0.3778,
#   'quant': 1595,
#   'amonut': 12,
#   'marketSum': 40},
#  {'itemcode': '302180',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 국채선물10년인버스',
#   'nowVal': 49545,
#   'risefall': '5',
#   'changeVal': -75,
#   'changeRate': -0.15,
#   'nav': 49538.0,
#   'threeMonthEarnRate': 2.8865,
#   'quant': 11,
#   'amonut': 0,
#   'marketSum': 40},
#  {'itemcode': '278420',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG ESG우수기업',
#   'nowVal': 9845,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.87,
#   'nav': 9844.0,
#   'threeMonthEarnRate': -2.3798,
#   'quant': 2581,
#   'amonut': 25,
#   'marketSum': 39},
#  {'itemcode': '217770',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 원유선물인버스(H)',
#   'nowVal': 5005,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -1.28,
#   'nav': None,
#   'threeMonthEarnRate': -15.6698,
#   'quant': 19499,
#   'amonut': 97,
#   'marketSum': 35},
#  {'itemcode': '295000',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 국채선물10년',
#   'nowVal': 54200,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.05,
#   'nav': 54185.0,
#   'threeMonthEarnRate': -2.5881,
#   'quant': 266,
#   'amonut': 14,
#   'marketSum': 35},
#  {'itemcode': '284990',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200에너지화학',
#   'nowVal': 14430,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.17,
#   'nav': 14430.0,
#   'threeMonthEarnRate': 2.4494,
#   'quant': 848,
#   'amonut': 12,
#   'marketSum': 35},
#  {'itemcode': '215620',
#   'etfTabCode': 2,
#   'itemname': 'HK S&P코리아로우볼',
#   'nowVal': 12370,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 12543.0,
#   'threeMonthEarnRate': -1.731,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 33},
#  {'itemcode': '267500',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#   'nowVal': 5960,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.17,
#   'nav': None,
#   'threeMonthEarnRate': -2.6144,
#   'quant': 2601,
#   'amonut': 15,
#   'marketSum': 33},
#  {'itemcode': '285020',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200철강소재',
#   'nowVal': 9650,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 1.31,
#   'nav': 9646.0,
#   'threeMonthEarnRate': -1.5809,
#   'quant': 11050,
#   'amonut': 106,
#   'marketSum': 31},
#  {'itemcode': '284980',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200금융',
#   'nowVal': 9040,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 1.4,
#   'nav': 9043.0,
#   'threeMonthEarnRate': 1.6301,
#   'quant': 2521,
#   'amonut': 22,
#   'marketSum': 31},
#  {'itemcode': '301400',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 코스닥150',
#   'nowVal': 14350,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.28,
#   'nav': 14492.0,
#   'threeMonthEarnRate': -4.3653,
#   'quant': 486,
#   'amonut': 6,
#   'marketSum': 29},
#  {'itemcode': '252720',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 모멘텀밸류',
#   'nowVal': 14330,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.53,
#   'nav': 14355.0,
#   'threeMonthEarnRate': -7.2192,
#   'quant': 2,
#   'amonut': 0,
#   'marketSum': 29},
#  {'itemcode': '397420',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 국채선물5년추종',
#   'nowVal': 49040,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.02,
#   'nav': 49018.0,
#   'threeMonthEarnRate': None,
#   'quant': 3,
#   'amonut': 0,
#   'marketSum': 24},
#  {'itemcode': '334700',
#   'etfTabCode': 5,
#   'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#   'nowVal': 5270,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 1.25,
#   'nav': None,
#   'threeMonthEarnRate': 23.5638,
#   'quant': 3110,
#   'amonut': 16,
#   'marketSum': 21},
#  {'itemcode': '287330',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200생활소비재',
#   'nowVal': 8285,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.91,
#   'nav': 8298.0,
#   'threeMonthEarnRate': -10.0923,
#   'quant': 2404,
#   'amonut': 19,
#   'marketSum': 20},
#  {'itemcode': '287310',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200경기소비재',
#   'nowVal': 11425,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.22,
#   'nav': 11416.0,
#   'threeMonthEarnRate': -6.0058,
#   'quant': 217,
#   'amonut': 2,
#   'marketSum': 16},
#  {'itemcode': '287320',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200산업재',
#   'nowVal': 11900,
#   'risefall': '2',
#   'changeVal': 115,
#   'changeRate': 0.98,
#   'nav': 11893.0,
#   'threeMonthEarnRate': -10.8615,
#   'quant': 56,
#   'amonut': 0,
#   'marketSum': 14}]

# %%
len(etfItemList)
# Out:
# 512

# %% [markdown]
# ## 데이터프레임 변환
# ### JSON 데이터를 pandas 의 데이터프레임 형태로 만들기

# %%
# 키-값 형태의 데이터를 데이터프레임으로 만듭니다.
df = pd.DataFrame(etfItemList)

# %% [markdown]
# ### 데이터 확인

# %%
# 데이터 프레임으로 잘 만들어 졌는지 상단 데이터의 일부만 미리보기 합니다.
df.head()
# Out:
#   itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0   069500           1              KODEX 200   39420        2        400
# 1   371460           4  TIGER 차이나전기차SOLACTIVE   17850        2        440
# 2   102110           1              TIGER 200   39460        2        415
# 3   153130           6             KODEX 단기채권  102965        5         -5
# 4   252670           3       KODEX 200선물인버스2X    2245        5        -50
#
#    changeRate       nav  threeMonthEarnRate      quant  amonut  marketSum
# 0        1.03   39436.0             -9.6680    2570170  101274      48270
# 1        2.53       NaN              7.2716    8417623  148973      22977
# 2        1.06   39472.0             -9.6074     430561   16985      21466
# 3        0.00  102964.0              0.1215      10120    1041      21277
# 4       -2.18    2239.0             20.0534  187196187  421296      19906

# %%
# 데이터 프레임으로 잘 만들어 졌는지 하단 데이터의 일부만 미리보기 합니다.
df.tail()
# Out:
#     itemcode  etfTabCode            itemname  nowVal risefall  changeVal  \
# 507   397420           6     KBSTAR 국채선물5년추종   49040        2         10
# 508   334700           5  KBSTAR 팔라듐선물인버스(H)    5270        2         65
# 509   287330           2     KBSTAR 200생활소비재    8285        2         75
# 510   287310           2     KBSTAR 200경기소비재   11425        2         25
# 511   287320           2       KBSTAR 200산업재   11900        2        115
#
#      changeRate      nav  threeMonthEarnRate  quant  amonut  marketSum
# 507        0.02  49018.0                 NaN      3       0         24
# 508        1.25      NaN             23.5638   3110      16         21
# 509        0.91   8298.0            -10.0923   2404      19         20
# 510        0.22  11416.0             -6.0058    217       2         16
# 511        0.98  11893.0            -10.8615     56       0         14

# %% [markdown]
# ## 파일 저장
# ### 파일명 만들기

# %%
# 파이썬 표준라이브러리인 datetime을 불러옵니다.
# 날짜를 만들어 저장하기 위해 오늘 날짜를 구합니다.

import datetime

today = datetime.datetime.today()
today = today.strftime("%Y%m%d")
today
# Out:
# '20211017'

# %%
# f-string 방식으로 파일명을 만들어 줍니다.
# eft_날짜_raw.csv 형태로 만듭니다.
file_name = f"etf_{today}_raw.csv"
file_name
# Out:
# 'etf_20211017_raw.csv'

# %% [markdown]
# ### 파일로 저장하고 불러오기

# %%
# csv 형태로 저장합니다. index 가 저장되지 않도록 합니다.
df.to_csv(file_name, index=False)

# %%
# 저장된 csv 파일을 읽어옵니다.
# itemcode 숫자 앞의 0 이 지워진다면 dtype={"itemcode": np.object} 로 타입을 지정해 주면 문자형태로 읽어옵니다.
pd.read_csv(file_name, dtype={"itemcode" : np.object})
# Out:
#     itemcode  etfTabCode               itemname  nowVal  risefall  changeVal  \
# 0     069500           1              KODEX 200   39420         2        400
# 1     371460           4  TIGER 차이나전기차SOLACTIVE   17850         2        440
# 2     102110           1              TIGER 200   39460         2        415
# 3     153130           6             KODEX 단기채권  102965         5         -5
# 4     252670           3       KODEX 200선물인버스2X    2245         5        -50
# ..       ...         ...                    ...     ...       ...        ...
# 507   397420           6        KBSTAR 국채선물5년추종   49040         2         10
# 508   334700           5     KBSTAR 팔라듐선물인버스(H)    5270         2         65
# 509   287330           2        KBSTAR 200생활소비재    8285         2         75
# 510   287310           2        KBSTAR 200경기소비재   11425         2         25
# 511   287320           2          KBSTAR 200산업재   11900         2        115
#
#      changeRate       nav  threeMonthEarnRate      quant  amonut  marketSum
# 0          1.03   39436.0             -9.6680    2570170  101274      48270
# 1          2.53       NaN              7.2716    8417623  148973      22977
# 2          1.06   39472.0             -9.6074     430561   16985      21466
# 3          0.00  102964.0              0.1215      10120    1041      21277
# 4         -2.18    2239.0             20.0534  187196187  421296      19906
# ..          ...       ...                 ...        ...     ...        ...
# 507        0.02   49018.0                 NaN          3       0         24
# 508        1.25       NaN             23.5638       3110      16         21
# 509        0.91    8298.0            -10.0923       2404      19         20
# 510        0.22   11416.0             -6.0058        217       2         16
# 511        0.98   11893.0            -10.8615         56       0         14
#
# [512 rows x 12 columns]
