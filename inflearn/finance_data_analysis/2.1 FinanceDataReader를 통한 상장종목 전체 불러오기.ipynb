# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/finance-data-analysis/blob/main/2.1%20FinanceDataReader%EB%A5%BC%20%ED%86%B5%ED%95%9C%20%EC%83%81%EC%9E%A5%EC%A2%85%EB%AA%A9%20%EC%A0%84%EC%B2%B4%20%EB%B6%88%EB%9F%AC%EC%98%A4%EA%B8%B0-input.ipynb)
#
#
#
# ## FinanceDataReader 란?
#
# * 한국 주식 가격, 미국주식 가격, 지수, 환율, 암호화폐 가격, 종목 리스팅 등 금융 데이터 수집 라이브러리
#
# * [FinanceData/FinanceDataReader: Financial data reader](https://github.com/FinanceData/FinanceDataReader)
# * [FinanceDataReader 사용자 안내서 | FinanceData](https://financedata.github.io/posts/finance-data-reader-users-guide.html)
# * https://pandas-datareader.readthedocs.io/en/latest/readers/index.html

# %% [markdown]
# ## 설치

# %%
# 주석을 풀고 설치해 주세요. 주석을 푸는 방법은 아래 코드의 맨 앞에 있는 #을 지워주시면 됩니다.
# !pip install -U finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in c:\users\kyung\anaconda3\lib\site-packages (0.9.31)
# Requirement already satisfied: lxml in c:\users\kyung\anaconda3\lib\site-packages (from finance-datareader) (4.6.3)
# Requirement already satisfied: tqdm in c:\users\kyung\anaconda3\lib\site-packages (from finance-datareader) (4.59.0)
# Requirement already satisfied: requests-file in c:\users\kyung\anaconda3\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\kyung\anaconda3\lib\site-packages (from finance-datareader) (2.25.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\kyung\anaconda3\lib\site-packages (from finance-datareader) (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\kyung\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\kyung\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\kyung\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\kyung\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.19.2->finance-datareader) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kyung\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kyung\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\kyung\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kyung\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.10)

# %% [markdown]
# ## 라이브러리 불러오기

# %%
# 데이터 분석을 위해 pandas 불러오기
import pandas as pd

# %%
# FinanceDataReader 를 fdr 별칭으로 불러옵니다.
# 라이브러리의 version을 확인하고 싶을 때는 .__version__ 으로 확인합니다. 
import FinanceDataReader as fdr
fdr.__version__
# Out:
# '0.9.31'

# %% [markdown]
# ## 한국거래소 상장종목 전체 가져오기

# %%
# 도움말을 보고자 할때는 ? 를 사용하고 소스코드를 볼 때는 ??를 사용합니다.
# 주피터 노트북에서는 함수나 메소드의 괄호 안에서 shift + tab 키를 누르면 도움말을 볼 수 있습니다.

# fdr.StockListing??

# %%
# KRX : KRX 종목 전체
# KOSPI : KOSPI 종목
# KOSDAQ : KOSDAQ 종목
# KONEX : KONEX 종목
# NASDAQ : 나스닥 종목
# NYSE : 뉴욕증권거래소 종목
# SP500 : S&P500 종목
df_krx = fdr.StockListing("KRX")

# %%
# 한국거래소 상장종목 전체 가져오기
df_krx
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S                  전자부품 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 7334  000547   KOSPI  흥국화재2우B                       NaN
# 7335  000545   KOSPI    흥국화재우                       NaN
# 7336  003280   KOSPI     흥아해운                    해상 운송업
# 7337  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7338  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 7334                             NaN         NaT         NaN
# 7335                             NaN         NaT         NaN
# 7336                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 7337                       설계 및 감리용역  2000-02-03         12월
# 7338  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#             Representative                       HomePage Region
# 0       박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                      박대현         http://www.ajnet.co.kr  서울특별시
# 2        채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                      정기로   http://www.apsholdings.co.kr    경기도
# 4                      김영주     http://www.apsystems.co.kr    경기도
# ...                    ...                            ...    ...
# 7334                   NaN                            NaN    NaN
# 7335                   NaN                            NaN    NaN
# 7336                   이환구         http://www.heung-a.com  서울특별시
# 7337  정영균, 이목운, 허철호 (각자대표)          http://www.heerim.com  서울특별시
# 7338                   김주환          http://www.hims.co.kr  인천광역시
#
# [7339 rows x 10 columns]

# %%
# 행과 열의 크기를 봅니다.(행, 열) 순
df_krx.shape
# Out:
# (7339, 10)

# %%
# 전체 데이터프레임의 요약정보를 봅니다.
df_krx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7339 entries, 0 to 7338
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          7339 non-null   object
#  1   Market          7339 non-null   object
#  2   Name            7339 non-null   object
#  3   Sector          2463 non-null   object
#  4   Industry        2444 non-null   object
#  5   ListingDate     2463 non-null   datetime64[ns]
#  6   SettleMonth     2463 non-null   object
#  7   Representative  2463 non-null   object
#  8   HomePage        2314 non-null   object
#  9   Region          2463 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 630.7+ KB

# %%
# 기술통계 값을 요약합니다.
df_krx.describe()
# Out:
# <ipython-input-19-df5b081ceac7>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_krx.describe()
#         Symbol Market  Name          Sector Industry          ListingDate  \
# count     7339   7339  7339            2463     2444                 2463
# unique    7339      3  7339             160     2293                 1820
# top     368770  KOSPI  SK가스  소프트웨어 개발 및 공급업   기업인수합병  1996-07-03 00:00:00
# freq         1   5672     1             144       27                    8
# first      NaN    NaN   NaN             NaN      NaN  1956-03-03 00:00:00
# last       NaN    NaN   NaN             NaN      NaN  2021-10-08 00:00:00
#
#        SettleMonth Representative                HomePage Region
# count         2463           2463                    2314   2463
# unique           9           2336                    2292     22
# top            12월              -  http://www.crown.co.kr  서울특별시
# freq          2402              5                       2    998
# first          NaN            NaN                     NaN    NaN
# last           NaN            NaN                     NaN    NaN

# %% [markdown]
# ## 파일로 저장하고 불러오기
# <img src="https://pandas.pydata.org/docs/_images/02_io_readwrite.svg">

# %%
# head 로 미리보기
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 박대현         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도

# %%
# to_csv로 Dataframe을 데이터 저장용 파일인 CSV 파일로 바꿀 수 있습니다.
# 의도하지 않은 index값이 생성되기 때문에 index=False로 지정
df_krx.to_csv("krx.csv", index=False)

# %%
# CSV로 저장된 파일을 다시 DataFrame으로 읽어서 확인해 봅니다.
pd.read_csv("krx.csv")
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S                  전자부품 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 7334  000547   KOSPI  흥국화재2우B                       NaN
# 7335  000545   KOSPI    흥국화재우                       NaN
# 7336  003280   KOSPI     흥아해운                    해상 운송업
# 7337  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7338  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 7334                             NaN         NaN         NaN
# 7335                             NaN         NaN         NaN
# 7336                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 7337                       설계 및 감리용역  2000-02-03         12월
# 7338  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#             Representative                       HomePage Region
# 0       박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                      박대현         http://www.ajnet.co.kr  서울특별시
# 2        채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                      정기로   http://www.apsholdings.co.kr    경기도
# 4                      김영주     http://www.apsystems.co.kr    경기도
# ...                    ...                            ...    ...
# 7334                   NaN                            NaN    NaN
# 7335                   NaN                            NaN    NaN
# 7336                   이환구         http://www.heung-a.com  서울특별시
# 7337  정영균, 이목운, 허철호 (각자대표)          http://www.heerim.com  서울특별시
# 7338                   김주환          http://www.hims.co.kr  인천광역시
#
# [7339 rows x 10 columns]
